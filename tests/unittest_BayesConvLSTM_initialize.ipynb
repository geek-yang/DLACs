# %% [markdown]
# # Copyright Netherlands eScience Center <br>
# ** Function     : Initialize BayesConvLSTM with known ConvLSTM weight** <br>
# ** Author       : Yang Liu ** <br>
# ** First Built  : 2020.03.27 ** <br>
# ** Last Update  : 2020.03.27 ** <br>
# ** Library      : Pytorth, Numpy, NetCDF4, os, iris, cartopy, dlacs, matplotlib **<br>
# Description     : This notebook serves to test the initialization of BayesConvLSTM with ConvLSTM weight. <br>
# <br>
#
# Return Values   : pkl model <br>

# %%
# %matplotlib inline

import sys
import warnings
import numbers

# for data loading
import os
from netCDF4 import Dataset
# for pre-processing and machine learning
import numpy as np
import sklearn
#import scipy
import torch
import torch.nn.functional

#sys.path.append(os.path.join('C:','Users','nosta','ML4Climate','Scripts','DLACs'))
sys.path.append("C:\\Users\\nosta\\ML4Climate\\Scripts\\DLACs")
sys.path.append("C:\\Users\\nosta\\ML4Climate\\Scripts\\DeepClim")
import dlacs
import dlacs.BayesConvLSTM
import dlacs.preprocess
import dlacs.function
import dlacs.saveNetCDF
# legacy
import deepclim
import deepclim.deepArray

# for visualization
import dlacs.visual
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import iris # also helps with regriding
import cartopy
import cartopy.crs as ccrs

# ignore all the DeprecationWarnings by pytorch
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %% [markdown]
# The testing device is Dell Inspirion 5680 with Intel Core i7-8700 x64 CPU and Nvidia GTX 1060 6GB GPU.<br>
# Here is a benchmark about cpu v.s. gtx 1060 <br>
# https://www.analyticsindiamag.com/deep-learning-tensorflow-benchmark-intel-i5-4210u-vs-geforce-nvidia-1060-6gb/

# %%
################################################################################# 
#########                           modelpath                             ########
#################################################################################
# path of initialization weight
init_path = 'C:\\Users\\nosta\\ML4Climate\\PredictArctic\\Maps'
# path of output
output_path = 'C:\\Users\\nosta\\ML4Climate\\PredictArctic\\BayesMaps'

# %%
if __name__=="__main__":
    print ('*******************  create basic dimensions for network  *********************')
    # specifications of neural network
    input_channels = 3
    hidden_channels = [3, 2, 1] # number of channels & hidden layers, the channels of last layer is the channels of output, too
    #hidden_channels = [3, 3, 3, 3, 2]
    #hidden_channels = [2]
    kernel_size = 3
    batch_size = 1
    #num_layers = 1
    learning_rate = 0.01
    num_epochs = 1500
# Out:
# *******************  create basic dimensions for network  *********************

# %%
    print ('*******************  load exsited LSTM model  *********************')
    # load model parameters
    #model = dlacs.BayesConvLSTM.BayesConvLSTM(input_channels, hidden_channels, kernel_size).to(device)
    #model.load_state_dict(torch.load(os.path.join(output_path, 'map_BayesConvLSTM_sic_ohc_Barents_hl_3_kernel_3_lr_0.01_epoch_1500_validSIC.pkl'),
    #                                 map_location=device))
    # load entire model
    model_init = torch.load(os.path.join(init_path, 'convlstm_era_sic_oras_ohc_Barents_hl_3_kernel_3_lr_0.005_epoch_1500_validSIC.pkl'))
    print(model_init)
# Out:
# *******************  load exsited LSTM model  *********************
# ConvLSTM(
#   (cell0): ConvLSTMCell(
#     (Wxi): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Whi): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (Wxf): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Whf): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (Wxc): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Whc): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (Wxo): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Who): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (cell1): ConvLSTMCell(
#     (Wxi): Conv2d(3, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Whi): Conv2d(2, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (Wxf): Conv2d(3, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Whf): Conv2d(2, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (Wxc): Conv2d(3, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Whc): Conv2d(2, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (Wxo): Conv2d(3, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Who): Conv2d(2, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (cell2): ConvLSTMCell(
#     (Wxi): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Whi): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (Wxf): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Whf): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (Wxc): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Whc): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (Wxo): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (Who): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
# )

# %%
    print ('*******************  extract the weight from ConvLSTM  *********************')
    weight_model_init = {}
    for name, param in model_init.named_parameters():
        weight_model_init['{}'.format(name)] = param.data
        
    print ('*******************  check the weight from ConvLSTM  *********************')
    for i in weight_model_init:
        print('{}'.format(i))
        print('{}'.format(weight_model_init['{}'.format(i)]))
        print ("=========================")
# Out:
# *******************  extract the weight from ConvLSTM  *********************
# *******************  check the weight from ConvLSTM  *********************
# cell0.Wxi.weight
# tensor([[[[-0.1253, -0.5814, -0.4379],
#           [-0.2001, -0.2750, -0.1768],
#           [-0.3347, -0.4417, -0.2793]],
#
#          [[ 0.2093,  0.1484,  0.1220],
#           [ 0.1573,  0.0237,  0.0926],
#           [-0.0204,  0.0380,  0.2156]],
#
#          [[-0.0252,  0.1174,  0.0601],
#           [ 0.0353, -0.0247, -0.1563],
#           [ 0.0043, -0.1410,  0.0755]]],
#
#
#         [[[-0.3883,  0.1526,  0.9933],
#           [ 0.0629,  0.8945,  0.7987],
#           [-0.0420,  1.1681,  0.1278]],
#
#          [[ 0.2115, -0.0215,  0.1117],
#           [ 0.0290, -0.0173,  0.1298],
#           [-0.1255,  0.0223, -0.0725]],
#
#          [[ 0.0404,  0.0021,  0.0034],
#           [ 0.2141,  0.0219, -0.0687],
#           [-0.0953, -0.0275, -0.0201]]],
#
#
#         [[[ 0.6254,  0.4591,  0.7186],
#           [ 0.4563,  0.2877,  0.3925],
#           [ 0.3539,  0.5635,  0.6305]],
#
#          [[ 0.3182,  0.1757,  0.2821],
#           [ 0.1969,  0.2908,  0.4320],
#           [ 0.1809,  0.3673,  0.1218]],
#
#          [[ 0.2055, -0.1039,  0.1036],
#           [ 0.0663, -0.0519, -0.0596],
#           [ 0.0829, -0.0409,  0.1999]]]], device='cuda:0')
# =========================
# cell0.Wxi.bias
# tensor([0.0814, 0.1309, 0.0942], device='cuda:0')
# =========================
# cell0.Whi.weight
# tensor([[[[-0.1767, -0.2109, -0.0229],
#           [ 0.0154, -0.1437, -0.2461],
#           [-0.0728, -0.1858, -0.3592]],
#
#          [[ 0.1805,  0.2205,  0.3085],
#           [-0.2097, -0.2815, -0.4478],
#           [-0.0415, -0.4404, -0.5156]],
#
#          [[-0.1144,  0.1047,  0.2035],
#           [-0.0951, -0.0404, -0.2226],
#           [ 0.2324, -0.0235, -0.0722]]],
#
#
#         [[[-0.0631,  0.0928,  0.1032],
#           [-0.0147,  0.0970,  0.1230],
#           [-0.0285,  0.2014, -0.0034]],
#
#          [[ 0.2279,  0.2875,  0.1575],
#           [ 0.3744,  0.3398,  0.2299],
#           [ 0.1191,  0.0552, -0.2109]],
#
#          [[ 0.2224,  0.3329, -0.2021],
#           [ 0.1498,  0.0213, -0.0651],
#           [ 0.3107,  0.0585,  0.0236]]],
#
#
#         [[[-0.1824, -0.1953, -0.2190],
#           [-0.3481, -0.3304, -0.2465],
#           [-0.3225, -0.0054, -0.2398]],
#
#          [[-0.0478, -0.1735, -0.1992],
#           [-0.0480, -0.1690, -0.4002],
#           [ 0.0744, -0.4171, -0.3072]],
#
#          [[-0.3407, -0.4296, -0.1385],
#           [ 0.1653, -0.2428, -0.1535],
#           [-0.0536, -0.2254, -0.2222]]]], device='cuda:0')
# =========================
# cell0.Wxf.weight
# tensor([[[[-0.4121, -0.6826, -0.3520],
#           [-0.2742, -0.2029, -0.3625],
#           [-0.4026, -0.4170, -0.2888]],
#
#          [[ 0.3896,  0.3103,  0.1137],
#           [ 0.2359,  0.2380,  0.0608],
#           [ 0.2491,  0.2826,  0.1375]],
#
#          [[-0.1268, -0.1012,  0.1499],
#           [-0.0392, -0.1192, -0.0408],
#           [ 0.1464, -0.0198, -0.0685]]],
#
#
#         [[[ 0.1662,  0.0827,  0.3841],
#           [ 0.3552,  0.4504,  0.2352],
#           [-0.1660,  0.3475,  0.1011]],
#
#          [[-0.1979, -0.2058, -0.1835],
#           [-0.1471, -0.3301, -0.4029],
#           [-0.1027, -0.4657, -0.2443]],
#
#          [[ 0.0783, -0.2355, -0.0442],
#           [-0.0548, -0.0947,  0.0252],
#           [ 0.1409, -0.0816, -0.1266]]],
#
#
#         [[[ 0.1794,  0.1802,  0.5444],
#           [ 0.1354, -0.0903, -0.0102],
#           [-0.3554, -0.6312,  0.2280]],
#
#          [[-0.1848, -0.0924, -0.0290],
#           [ 0.0093, -0.0618,  0.0603],
#           [ 0.1451, -0.1146,  0.0952]],
#
#          [[-0.2016, -0.1298, -0.1664],
#           [ 0.1210,  0.0412,  0.1576],
#           [ 0.0204,  0.0874,  0.1456]]]], device='cuda:0')
# =========================
# cell0.Wxf.bias
# tensor([ 0.0134, -0.0948, -0.3745], device='cuda:0')
# =========================
# cell0.Whf.weight
# tensor([[[[-0.3133, -0.1305, -0.0849],
#           [-0.1829, -0.0571, -0.0571],
#           [-0.3783, -0.3356, -0.1009]],
#
#          [[ 0.0489,  0.1664,  0.0372],
#           [-0.1500,  0.0045, -0.2021],
#           [-0.3177,  0.0295, -0.3257]],
#
#          [[-0.2030,  0.0466,  0.2029],
#           [ 0.2714,  0.3080,  0.2502],
#           [-0.0606,  0.0421, -0.1909]]],
#
#
#         [[[-0.2590, -0.0154, -0.2294],
#           [-0.0678, -0.3233, -0.1098],
#           [-0.4460, -0.3662, -0.2803]],
#
#          [[-0.3899,  0.2836,  0.1534],
#           [ 0.0445,  0.1353, -0.0806],
#           [-0.0889, -0.1227, -0.2863]],
#
#          [[ 0.0264, -0.1281,  0.0387],
#           [ 0.1712, -0.2135,  0.3499],
#           [ 0.3553,  0.3358, -0.0005]]],
#
#
#         [[[ 0.1297,  0.0671,  0.0807],
#           [-0.0819,  0.1713, -0.0099],
#           [ 0.1034, -0.0495, -0.0953]],
#
#          [[ 0.2480,  0.1646,  0.1730],
#           [ 0.4175,  0.1853, -0.3013],
#           [ 0.0233,  0.0251, -0.4156]],
#
#          [[-0.0946, -0.1607, -0.2620],
#           [ 0.2175, -0.0268,  0.0623],
#           [ 0.0893,  0.0103, -0.2094]]]], device='cuda:0')
# =========================
# cell0.Wxc.weight
# tensor([[[[ 1.3437e-01,  1.9195e-01, -4.1489e-02],
#           [-2.4575e-01, -3.7721e-02,  2.4778e-02],
#           [-3.1593e-01,  1.7801e-02, -2.1476e-01]],
#
#          [[-1.1031e-01, -2.8136e-01, -1.3335e-01],
#           [-2.7622e-01, -1.2709e-01, -1.9126e-01],
#           [-8.7683e-02, -1.5605e-01, -4.0112e-01]],
#
#          [[-9.9398e-02, -7.6207e-03, -2.3469e-01],
#           [-1.4841e-02, -4.6877e-03, -2.3049e-01],
#           [ 4.8391e-02, -2.6290e-01, -8.5342e-02]]],
#
#
#         [[[ 4.7727e-01,  2.9238e-01, -4.8050e-01],
#           [-2.9410e-01, -8.0141e-01, -3.6673e-01],
#           [ 4.0152e-01, -7.3166e-01, -1.7754e-02]],
#
#          [[-5.3332e-02, -5.2800e-02, -8.9933e-04],
#           [ 1.4747e-01, -1.4525e-01,  5.2723e-02],
#           [-9.6994e-02, -1.1822e-01, -1.0870e-01]],
#
#          [[ 1.1167e-01, -4.8255e-02, -1.4649e-01],
#           [ 1.0409e-01, -3.6430e-02,  4.1641e-02],
#           [-3.8830e-02, -7.2123e-02,  1.7255e-02]]],
#
#
#         [[[ 1.4150e-01, -8.2355e-01, -1.2854e+00],
#           [-8.1030e-02,  4.3617e-01, -4.7193e-01],
#           [-5.0076e-01,  1.0191e+00, -5.8422e-01]],
#
#          [[ 4.9934e-02, -3.2617e-02,  1.3765e-04],
#           [ 5.2526e-02, -3.5289e-02, -2.7974e-02],
#           [ 5.2034e-02, -1.1373e-02, -4.5031e-02]],
#
#          [[-7.3974e-02, -1.1575e-02, -1.2715e-01],
#           [-5.0395e-02,  9.6784e-02,  1.6987e-01],
#           [ 1.2260e-01, -2.0179e-02, -1.0536e-01]]]], device='cuda:0')
# =========================
# cell0.Wxc.bias
# tensor([-0.2399,  0.1520,  0.1440], device='cuda:0')
# =========================
# cell0.Whc.weight
# tensor([[[[-0.0406,  0.0033, -0.1014],
#           [-0.0597, -0.1090, -0.1169],
#           [-0.0271,  0.1963,  0.0112]],
#
#          [[-0.1981, -0.1882, -0.2189],
#           [ 0.2025,  0.0133,  0.0695],
#           [ 0.1819,  0.3210,  0.1145]],
#
#          [[-0.0786, -0.5596, -0.0559],
#           [-0.0434, -0.2108,  0.0557],
#           [ 0.1855, -0.1270, -0.0819]]],
#
#
#         [[[ 0.0534,  0.0480,  0.0964],
#           [ 0.0406, -0.0442,  0.0769],
#           [ 0.0727,  0.0155,  0.1451]],
#
#          [[ 0.1486, -0.1504,  0.0514],
#           [-0.0478, -0.2673, -0.0397],
#           [-0.0718, -0.0804, -0.0530]],
#
#          [[-0.0105, -0.0497,  0.0403],
#           [ 0.0911,  0.1233, -0.0655],
#           [-0.1865, -0.2003, -0.0833]]],
#
#
#         [[[ 0.0976, -0.1416,  0.1186],
#           [ 0.0070,  0.2275, -0.0035],
#           [ 0.0446,  0.0362, -0.0608]],
#
#          [[-0.2944, -0.3250, -0.2284],
#           [-0.0670, -0.1026, -0.0181],
#           [ 0.0873, -0.0662,  0.0128]],
#
#          [[ 0.0266, -0.1168,  0.0971],
#           [ 0.0719, -0.6748, -0.1103],
#           [ 0.0964, -0.0152, -0.0607]]]], device='cuda:0')
# =========================
# cell0.Wxo.weight
# tensor([[[[-0.1339, -0.1571, -0.0804],
#           [ 0.7952,  0.9405,  0.4178],
#           [-1.0535, -1.2820, -1.3843]],
#
#          [[ 0.5676,  0.2295,  0.0152],
#           [ 0.4201,  0.2303,  0.0951],
#           [ 0.2893,  0.3975,  0.1099]],
#
#          [[ 0.1884, -0.1050,  0.0701],
#           [-0.1247,  0.1273,  0.0333],
#           [-0.1356,  0.1017,  0.1139]]],
#
#
#         [[[ 0.1761,  0.5265,  0.3938],
#           [ 0.3139,  0.4074,  0.6173],
#           [ 0.3349,  0.5943,  0.5797]],
#
#          [[-0.0409, -0.0555, -0.1679],
#           [ 0.0496, -0.1028, -0.1609],
#           [-0.1892, -0.1774, -0.0153]],
#
#          [[ 0.0428, -0.1369,  0.0255],
#           [-0.0210, -0.0985,  0.1046],
#           [-0.0562,  0.0859,  0.0974]]],
#
#
#         [[[ 0.6893,  0.5202,  0.6389],
#           [ 0.3904,  0.3991,  0.5056],
#           [ 0.4855,  0.5800,  0.6191]],
#
#          [[ 0.3042,  0.3213,  0.4066],
#           [ 0.2416,  0.1951,  0.3975],
#           [ 0.2434,  0.1513,  0.3992]],
#
#          [[ 0.1757, -0.0271, -0.1072],
#           [ 0.1259, -0.0414,  0.0578],
#           [-0.0669,  0.2698,  0.1323]]]], device='cuda:0')
# =========================
# cell0.Wxo.bias
# tensor([0.1341, 0.0072, 0.2107], device='cuda:0')
# =========================
# cell0.Who.weight
# tensor([[[[ 4.2960e-02, -1.8782e-02,  3.4331e-02],
#           [-3.7617e-01, -2.6454e-01, -3.5489e-01],
#           [-2.6716e-01,  2.9074e-02, -1.0423e-01]],
#
#          [[-4.6629e-01, -4.4109e-01,  1.7605e-01],
#           [-4.1722e-01, -3.2188e-01, -2.3315e-01],
#           [-3.6009e-01,  2.8799e-01,  5.8393e-01]],
#
#          [[-1.3392e+00,  2.5167e-01,  6.6726e-01],
#           [-8.2628e-01,  1.4399e-01, -6.3494e-01],
#           [-1.6277e-01, -4.5857e-01,  6.9736e-01]]],
#
#
#         [[[-2.0841e-02, -1.8111e-01, -2.4765e-02],
#           [ 1.4310e-02, -9.9407e-02, -2.0886e-01],
#           [-1.8029e-01, -2.0063e-01, -2.1434e-01]],
#
#          [[-3.2561e-02, -4.7475e-02, -1.6084e-01],
#           [-1.1912e-01, -4.5133e-02, -8.2083e-02],
#           [-2.4669e-01, -3.4841e-02, -2.6680e-01]],
#
#          [[-2.4766e-01,  1.8113e-01,  3.4192e-02],
#           [-3.7504e-01, -2.2193e-01, -1.3561e-01],
#           [-2.7016e-01, -2.1256e-01,  1.3686e-01]]],
#
#
#         [[[-3.9142e-01, -1.2422e-01, -2.0015e-01],
#           [-1.1786e-01, -1.9750e-01, -2.9472e-01],
#           [-2.5315e-01, -2.0551e-01, -9.7249e-02]],
#
#          [[-9.9875e-02, -2.4524e-01, -4.6238e-01],
#           [-1.1185e-01, -3.9753e-01, -3.6032e-01],
#           [-2.6651e-01, -2.0156e-01, -4.2616e-01]],
#
#          [[-1.5242e-01, -2.2463e-01, -1.2129e-05],
#           [ 1.0533e-02, -3.5005e-01, -4.8768e-01],
#           [ 1.0951e-01, -1.6355e-01, -2.4281e-02]]]], device='cuda:0')
# =========================
# cell1.Wxi.weight
# tensor([[[[-0.0230,  0.0466, -0.0035],
#           [-0.1342, -0.3288,  0.0476],
#           [-0.1025, -0.2917, -0.2485]],
#
#          [[-0.4088, -0.2320, -0.4693],
#           [-0.1855, -0.3493, -0.2882],
#           [-0.5222, -0.3000, -0.4180]],
#
#          [[ 0.3004,  0.0048,  0.4431],
#           [ 0.1859, -0.0416,  0.1919],
#           [-0.9506, -1.1509, -0.5154]]],
#
#
#         [[[-0.3081, -0.0979,  0.0215],
#           [-0.1934, -0.3703, -0.0877],
#           [-0.0184, -0.2374, -0.2140]],
#
#          [[-0.7249, -0.3978, -0.5167],
#           [-0.5642, -0.3773, -0.2113],
#           [-0.3611, -0.1650, -0.1354]],
#
#          [[-0.2621, -0.3600, -0.2737],
#           [-0.3802,  0.1122, -0.1374],
#           [-0.6005,  0.0567, -0.0969]]]], device='cuda:0')
# =========================
# cell1.Wxi.bias
# tensor([0.1796, 0.3558], device='cuda:0')
# =========================
# cell1.Whi.weight
# tensor([[[[-0.2599, -0.2471, -0.0116],
#           [-0.0359, -0.1602, -0.2456],
#           [-0.2524, -0.2631, -0.1373]],
#
#          [[-0.2223, -0.0630, -0.3129],
#           [ 0.1684,  0.2002, -0.1615],
#           [ 0.0063,  0.1030,  0.1251]]],
#
#
#         [[[-0.0649, -0.0351, -0.3270],
#           [-0.4118, -0.2165, -0.0317],
#           [-0.1581,  0.1536,  0.0669]],
#
#          [[-0.1150, -0.2266, -0.2423],
#           [-0.2006,  0.2029, -0.0150],
#           [-0.0281, -0.0202,  0.1173]]]], device='cuda:0')
# =========================
# cell1.Wxf.weight
# tensor([[[[ 0.2271,  0.0177,  0.0970],
#           [ 0.2124,  0.0111,  0.1750],
#           [ 0.2087,  0.1379,  0.2247]],
#
#          [[-0.0665, -0.2313, -0.0773],
#           [-0.0363, -0.2852, -0.0278],
#           [ 0.1338, -0.1602,  0.2575]],
#
#          [[ 0.4393, -0.1570,  0.1656],
#           [-0.0135,  0.0504,  0.1961],
#           [ 0.2666,  0.0865,  0.4987]]],
#
#
#         [[[ 0.1147,  0.0706,  0.2466],
#           [-0.0909,  0.0737,  0.0499],
#           [ 0.1154,  0.1244,  0.1006]],
#
#          [[-0.2593,  0.1307, -0.4280],
#           [-0.1966, -0.1842,  0.0765],
#           [ 0.2303,  0.1559, -0.1207]],
#
#          [[ 0.3023, -0.2362, -0.0082],
#           [-0.1752, -0.1896, -0.0508],
#           [-0.7265,  0.4676, -0.0972]]]], device='cuda:0')
# =========================
# cell1.Wxf.bias
# tensor([-0.1626, -0.0935], device='cuda:0')
# =========================
# cell1.Whf.weight
# tensor([[[[-0.0050, -0.1508,  0.0982],
#           [ 0.2273, -0.1300, -0.1574],
#           [-0.1182,  0.0278, -0.1470]],
#
#          [[ 0.2029,  0.0716, -0.1574],
#           [-0.1065,  0.0980, -0.2075],
#           [-0.0340,  0.1039,  0.1417]]],
#
#
#         [[[ 0.4104,  0.1398, -0.1097],
#           [ 0.2717, -0.0932,  0.1196],
#           [ 0.2818,  0.3693,  0.3636]],
#
#          [[-0.4093, -0.3568, -0.2878],
#           [-0.1270, -0.1954, -0.0195],
#           [-0.1502,  0.1416,  0.0186]]]], device='cuda:0')
# =========================
# cell1.Wxc.weight
# tensor([[[[ 0.1311, -0.1579, -0.0893],
#           [-0.1369, -0.0413, -0.1152],
#           [ 0.1115,  0.0096,  0.0128]],
#
#          [[-0.0321,  0.0596,  0.2334],
#           [ 0.1119,  0.4477,  0.2386],
#           [ 0.1429,  0.3463, -0.0642]],
#
#          [[-0.1662,  0.4114, -0.1700],
#           [ 0.1268,  0.0444, -0.0037],
#           [ 0.5892,  0.8325,  0.1635]]],
#
#
#         [[[ 0.1256,  0.0563,  0.2004],
#           [-0.0175, -0.1037, -0.0476],
#           [ 0.2199,  0.1425,  0.2119]],
#
#          [[ 0.0552, -0.5350,  0.0430],
#           [-0.2111, -0.4868, -0.3019],
#           [-0.2745, -0.0128,  0.2637]],
#
#          [[-0.2361,  0.4779, -0.1536],
#           [-0.1088,  0.1051, -0.0256],
#           [-0.3173, -0.3641,  0.0634]]]], device='cuda:0')
# =========================
# cell1.Wxc.bias
# tensor([-0.1765,  0.1234], device='cuda:0')
# =========================
# cell1.Whc.weight
# tensor([[[[ 0.1160,  0.0482,  0.1377],
#           [-0.0470,  0.0136, -0.1136],
#           [-0.0874,  0.1289, -0.0385]],
#
#          [[-0.0085,  0.0890,  0.0140],
#           [ 0.1578,  0.0026,  0.1002],
#           [-0.1523, -0.0213, -0.0998]]],
#
#
#         [[[ 0.2214,  0.2761,  0.2161],
#           [ 0.2073,  0.1390,  0.0914],
#           [ 0.1246,  0.1485,  0.1491]],
#
#          [[-0.0073,  0.0287,  0.0333],
#           [-0.0947, -0.3660, -0.0128],
#           [ 0.0494, -0.1545,  0.1584]]]], device='cuda:0')
# =========================
# cell1.Wxo.weight
# tensor([[[[ 0.0822,  0.1102,  0.1202],
#           [ 0.0527, -0.3006,  0.0444],
#           [-0.1792,  0.0051,  0.0782]],
#
#          [[-0.1164, -0.1980, -0.2210],
#           [-0.0488, -0.2474, -0.3208],
#           [-0.0128, -0.3469,  0.0494]],
#
#          [[ 0.1810, -0.7069,  0.1492],
#           [ 0.0196,  0.1685,  0.7676],
#           [ 0.0408, -0.8269,  0.1767]]],
#
#
#         [[[-0.0922, -0.1962, -0.1657],
#           [-0.3513, -0.0763, -0.1353],
#           [-0.3328, -0.1116, -0.1919]],
#
#          [[-0.6429, -0.4590, -0.3655],
#           [-0.3234, -0.5031, -0.2389],
#           [-0.3423, -0.1017, -0.0550]],
#
#          [[-0.3882, -0.2876, -0.5897],
#           [-0.2182,  0.3292,  0.1633],
#           [-0.4553,  0.3573,  0.0255]]]], device='cuda:0')
# =========================
# cell1.Wxo.bias
# tensor([ 0.3058, -0.0363], device='cuda:0')
# =========================
# cell1.Who.weight
# tensor([[[[-0.0537, -0.2184, -0.1960],
#           [ 0.0793, -0.0469,  0.1047],
#           [-0.1044,  0.0407,  0.2452]],
#
#          [[ 0.2056, -0.0212, -0.0146],
#           [-0.1184, -0.0156, -0.1892],
#           [ 0.0634,  0.0955, -0.0668]]],
#
#
#         [[[-0.5748, -0.0220, -0.2701],
#           [-0.4534, -0.1483, -0.1806],
#           [-0.0301, -0.2486,  0.0256]],
#
#          [[-0.3560, -0.2396, -0.0017],
#           [ 0.0394, -0.2146,  0.1541],
#           [ 0.0102, -0.1503,  0.0513]]]], device='cuda:0')
# =========================
# cell2.Wxi.weight
# tensor([[[[-0.6423, -0.3906, -0.1379],
#           [-1.1632, -0.6641, -0.7773],
#           [-0.5520, -0.0763, -0.2624]],
#
#          [[ 0.2504,  0.3180,  0.4318],
#           [ 0.6036,  1.3772,  0.1379],
#           [-0.0039,  0.0772,  0.0623]]]], device='cuda:0')
# =========================
# cell2.Wxi.bias
# tensor([-0.0115], device='cuda:0')
# =========================
# cell2.Whi.weight
# tensor([[[[-0.0863, -0.4658, -0.3794],
#           [-0.3827, -0.0875, -0.5075],
#           [ 0.0129, -0.1447,  0.2190]]]], device='cuda:0')
# =========================
# cell2.Wxf.weight
# tensor([[[[ 0.0266,  0.0258,  0.0367],
#           [-0.3121, -0.1775, -0.0122],
#           [ 0.2625,  0.2606,  0.0774]],
#
#          [[-0.0209,  0.1912,  0.1674],
#           [ 0.3926,  0.8309,  0.1411],
#           [ 0.1646,  0.0113, -0.2837]]]], device='cuda:0')
# =========================
# cell2.Wxf.bias
# tensor([-0.8602], device='cuda:0')
# =========================
# cell2.Whf.weight
# tensor([[[[ 0.3847, -0.0420,  0.2152],
#           [-0.2059,  0.1114, -0.0909],
#           [-0.2933,  0.1623,  0.3783]]]], device='cuda:0')
# =========================
# cell2.Wxc.weight
# tensor([[[[-0.0833, -0.2570,  0.1175],
#           [-0.5897, -0.3605, -0.2642],
#           [ 0.0161,  0.1338, -0.0336]],
#
#          [[-0.0422, -0.1120,  0.0646],
#           [ 0.1847,  0.9165, -0.1244],
#           [-0.0860, -0.0492, -0.1583]]]], device='cuda:0')
# =========================
# cell2.Wxc.bias
# tensor([0.0313], device='cuda:0')
# =========================
# cell2.Whc.weight
# tensor([[[[-0.0504, -0.0648, -0.1043],
#           [-0.0942, -0.1594, -0.0390],
#           [ 0.0510, -0.0974, -0.0302]]]], device='cuda:0')
# =========================
# cell2.Wxo.weight
# tensor([[[[-0.7113, -0.3272, -0.2529],
#           [-0.9133, -0.6301, -0.4213],
#           [ 0.0056,  0.2432, -0.0953]],
#
#          [[-0.2234, -0.0975,  0.0768],
#           [ 0.2590,  0.9676, -0.1638],
#           [ 0.0367,  0.2603, -0.0561]]]], device='cuda:0')
# =========================
# cell2.Wxo.bias
# tensor([-0.0644], device='cuda:0')
# =========================
# cell2.Who.weight
# tensor([[[[-0.3425,  0.1325, -0.1561],
#           [ 0.3030,  0.1554,  0.3414],
#           [ 0.4759, -0.1258, -0.3464]]]], device='cuda:0')
# =========================

# %%
    print ('*******************  check the environment  *********************')
    print ("Pytorch version {}".format(torch.__version__))
    # check if CUDA is available
    use_cuda = torch.cuda.is_available()
    print("Is CUDA available? {}".format(use_cuda))
    # CUDA settings torch.__version__ must > 0.4
    # !!! This is important for the model!!! The first option is gpu
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# *******************  check the environment  *********************
# Pytorch version 1.1.0
# Is CUDA available? True

# %%
    print ('*******************  initialize BayesConvLSTM with given weight  *********************')
    # initialize our model
    model = dlacs.BayesConvLSTM.BayesConvLSTM(input_channels, hidden_channels, kernel_size,
                                              cell_type='reduced', weight_dict = weight_model_init).to(device)
# Out:
# *******************  initialize BayesConvLSTM with given weight  *********************
# !@#$% The network will be built with reduced size BayesConvLSTM cell. !@#$%

# %%
    print ('*******************  check wieght matrix of BayesConvLSTM  *********************')
    for name, param in model.named_parameters():
        if param.requires_grad:
            print (name)
            print (param.data)
            print (param.size())
            print ("=========================")
# Out:
# *******************  check wieght matrix of BayesConvLSTM  *********************
# cell0.Wxi_mu
# tensor([[[[-0.1253, -0.5814, -0.4379],
#           [-0.2001, -0.2750, -0.1768],
#           [-0.3347, -0.4417, -0.2793]],
#
#          [[ 0.2093,  0.1484,  0.1220],
#           [ 0.1573,  0.0237,  0.0926],
#           [-0.0204,  0.0380,  0.2156]],
#
#          [[-0.0252,  0.1174,  0.0601],
#           [ 0.0353, -0.0247, -0.1563],
#           [ 0.0043, -0.1410,  0.0755]]],
#
#
#         [[[-0.3883,  0.1526,  0.9933],
#           [ 0.0629,  0.8945,  0.7987],
#           [-0.0420,  1.1681,  0.1278]],
#
#          [[ 0.2115, -0.0215,  0.1117],
#           [ 0.0290, -0.0173,  0.1298],
#           [-0.1255,  0.0223, -0.0725]],
#
#          [[ 0.0404,  0.0021,  0.0034],
#           [ 0.2141,  0.0219, -0.0687],
#           [-0.0953, -0.0275, -0.0201]]],
#
#
#         [[[ 0.6254,  0.4591,  0.7186],
#           [ 0.4563,  0.2877,  0.3925],
#           [ 0.3539,  0.5635,  0.6305]],
#
#          [[ 0.3182,  0.1757,  0.2821],
#           [ 0.1969,  0.2908,  0.4320],
#           [ 0.1809,  0.3673,  0.1218]],
#
#          [[ 0.2055, -0.1039,  0.1036],
#           [ 0.0663, -0.0519, -0.0596],
#           [ 0.0829, -0.0409,  0.1999]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Whi_mu
# tensor([[[[-0.1767, -0.2109, -0.0229],
#           [ 0.0154, -0.1437, -0.2461],
#           [-0.0728, -0.1858, -0.3592]],
#
#          [[ 0.1805,  0.2205,  0.3085],
#           [-0.2097, -0.2815, -0.4478],
#           [-0.0415, -0.4404, -0.5156]],
#
#          [[-0.1144,  0.1047,  0.2035],
#           [-0.0951, -0.0404, -0.2226],
#           [ 0.2324, -0.0235, -0.0722]]],
#
#
#         [[[-0.0631,  0.0928,  0.1032],
#           [-0.0147,  0.0970,  0.1230],
#           [-0.0285,  0.2014, -0.0034]],
#
#          [[ 0.2279,  0.2875,  0.1575],
#           [ 0.3744,  0.3398,  0.2299],
#           [ 0.1191,  0.0552, -0.2109]],
#
#          [[ 0.2224,  0.3329, -0.2021],
#           [ 0.1498,  0.0213, -0.0651],
#           [ 0.3107,  0.0585,  0.0236]]],
#
#
#         [[[-0.1824, -0.1953, -0.2190],
#           [-0.3481, -0.3304, -0.2465],
#           [-0.3225, -0.0054, -0.2398]],
#
#          [[-0.0478, -0.1735, -0.1992],
#           [-0.0480, -0.1690, -0.4002],
#           [ 0.0744, -0.4171, -0.3072]],
#
#          [[-0.3407, -0.4296, -0.1385],
#           [ 0.1653, -0.2428, -0.1535],
#           [-0.0536, -0.2254, -0.2222]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Wxf_mu
# tensor([[[[-0.4121, -0.6826, -0.3520],
#           [-0.2742, -0.2029, -0.3625],
#           [-0.4026, -0.4170, -0.2888]],
#
#          [[ 0.3896,  0.3103,  0.1137],
#           [ 0.2359,  0.2380,  0.0608],
#           [ 0.2491,  0.2826,  0.1375]],
#
#          [[-0.1268, -0.1012,  0.1499],
#           [-0.0392, -0.1192, -0.0408],
#           [ 0.1464, -0.0198, -0.0685]]],
#
#
#         [[[ 0.1662,  0.0827,  0.3841],
#           [ 0.3552,  0.4504,  0.2352],
#           [-0.1660,  0.3475,  0.1011]],
#
#          [[-0.1979, -0.2058, -0.1835],
#           [-0.1471, -0.3301, -0.4029],
#           [-0.1027, -0.4657, -0.2443]],
#
#          [[ 0.0783, -0.2355, -0.0442],
#           [-0.0548, -0.0947,  0.0252],
#           [ 0.1409, -0.0816, -0.1266]]],
#
#
#         [[[ 0.1794,  0.1802,  0.5444],
#           [ 0.1354, -0.0903, -0.0102],
#           [-0.3554, -0.6312,  0.2280]],
#
#          [[-0.1848, -0.0924, -0.0290],
#           [ 0.0093, -0.0618,  0.0603],
#           [ 0.1451, -0.1146,  0.0952]],
#
#          [[-0.2016, -0.1298, -0.1664],
#           [ 0.1210,  0.0412,  0.1576],
#           [ 0.0204,  0.0874,  0.1456]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Whf_mu
# tensor([[[[-0.3133, -0.1305, -0.0849],
#           [-0.1829, -0.0571, -0.0571],
#           [-0.3783, -0.3356, -0.1009]],
#
#          [[ 0.0489,  0.1664,  0.0372],
#           [-0.1500,  0.0045, -0.2021],
#           [-0.3177,  0.0295, -0.3257]],
#
#          [[-0.2030,  0.0466,  0.2029],
#           [ 0.2714,  0.3080,  0.2502],
#           [-0.0606,  0.0421, -0.1909]]],
#
#
#         [[[-0.2590, -0.0154, -0.2294],
#           [-0.0678, -0.3233, -0.1098],
#           [-0.4460, -0.3662, -0.2803]],
#
#          [[-0.3899,  0.2836,  0.1534],
#           [ 0.0445,  0.1353, -0.0806],
#           [-0.0889, -0.1227, -0.2863]],
#
#          [[ 0.0264, -0.1281,  0.0387],
#           [ 0.1712, -0.2135,  0.3499],
#           [ 0.3553,  0.3358, -0.0005]]],
#
#
#         [[[ 0.1297,  0.0671,  0.0807],
#           [-0.0819,  0.1713, -0.0099],
#           [ 0.1034, -0.0495, -0.0953]],
#
#          [[ 0.2480,  0.1646,  0.1730],
#           [ 0.4175,  0.1853, -0.3013],
#           [ 0.0233,  0.0251, -0.4156]],
#
#          [[-0.0946, -0.1607, -0.2620],
#           [ 0.2175, -0.0268,  0.0623],
#           [ 0.0893,  0.0103, -0.2094]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Wxc_mu
# tensor([[[[ 1.3437e-01,  1.9195e-01, -4.1489e-02],
#           [-2.4575e-01, -3.7721e-02,  2.4778e-02],
#           [-3.1593e-01,  1.7801e-02, -2.1476e-01]],
#
#          [[-1.1031e-01, -2.8136e-01, -1.3335e-01],
#           [-2.7622e-01, -1.2709e-01, -1.9126e-01],
#           [-8.7683e-02, -1.5605e-01, -4.0112e-01]],
#
#          [[-9.9398e-02, -7.6207e-03, -2.3469e-01],
#           [-1.4841e-02, -4.6877e-03, -2.3049e-01],
#           [ 4.8391e-02, -2.6290e-01, -8.5342e-02]]],
#
#
#         [[[ 4.7727e-01,  2.9238e-01, -4.8050e-01],
#           [-2.9410e-01, -8.0141e-01, -3.6673e-01],
#           [ 4.0152e-01, -7.3166e-01, -1.7754e-02]],
#
#          [[-5.3332e-02, -5.2800e-02, -8.9933e-04],
#           [ 1.4747e-01, -1.4525e-01,  5.2723e-02],
#           [-9.6994e-02, -1.1822e-01, -1.0870e-01]],
#
#          [[ 1.1167e-01, -4.8255e-02, -1.4649e-01],
#           [ 1.0409e-01, -3.6430e-02,  4.1641e-02],
#           [-3.8830e-02, -7.2123e-02,  1.7255e-02]]],
#
#
#         [[[ 1.4150e-01, -8.2355e-01, -1.2854e+00],
#           [-8.1030e-02,  4.3617e-01, -4.7193e-01],
#           [-5.0076e-01,  1.0191e+00, -5.8422e-01]],
#
#          [[ 4.9934e-02, -3.2617e-02,  1.3765e-04],
#           [ 5.2526e-02, -3.5289e-02, -2.7974e-02],
#           [ 5.2034e-02, -1.1373e-02, -4.5031e-02]],
#
#          [[-7.3974e-02, -1.1575e-02, -1.2715e-01],
#           [-5.0395e-02,  9.6784e-02,  1.6987e-01],
#           [ 1.2260e-01, -2.0179e-02, -1.0536e-01]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Whc_mu
# tensor([[[[-0.0406,  0.0033, -0.1014],
#           [-0.0597, -0.1090, -0.1169],
#           [-0.0271,  0.1963,  0.0112]],
#
#          [[-0.1981, -0.1882, -0.2189],
#           [ 0.2025,  0.0133,  0.0695],
#           [ 0.1819,  0.3210,  0.1145]],
#
#          [[-0.0786, -0.5596, -0.0559],
#           [-0.0434, -0.2108,  0.0557],
#           [ 0.1855, -0.1270, -0.0819]]],
#
#
#         [[[ 0.0534,  0.0480,  0.0964],
#           [ 0.0406, -0.0442,  0.0769],
#           [ 0.0727,  0.0155,  0.1451]],
#
#          [[ 0.1486, -0.1504,  0.0514],
#           [-0.0478, -0.2673, -0.0397],
#           [-0.0718, -0.0804, -0.0530]],
#
#          [[-0.0105, -0.0497,  0.0403],
#           [ 0.0911,  0.1233, -0.0655],
#           [-0.1865, -0.2003, -0.0833]]],
#
#
#         [[[ 0.0976, -0.1416,  0.1186],
#           [ 0.0070,  0.2275, -0.0035],
#           [ 0.0446,  0.0362, -0.0608]],
#
#          [[-0.2944, -0.3250, -0.2284],
#           [-0.0670, -0.1026, -0.0181],
#           [ 0.0873, -0.0662,  0.0128]],
#
#          [[ 0.0266, -0.1168,  0.0971],
#           [ 0.0719, -0.6748, -0.1103],
#           [ 0.0964, -0.0152, -0.0607]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Wxo_mu
# tensor([[[[-0.1339, -0.1571, -0.0804],
#           [ 0.7952,  0.9405,  0.4178],
#           [-1.0535, -1.2820, -1.3843]],
#
#          [[ 0.5676,  0.2295,  0.0152],
#           [ 0.4201,  0.2303,  0.0951],
#           [ 0.2893,  0.3975,  0.1099]],
#
#          [[ 0.1884, -0.1050,  0.0701],
#           [-0.1247,  0.1273,  0.0333],
#           [-0.1356,  0.1017,  0.1139]]],
#
#
#         [[[ 0.1761,  0.5265,  0.3938],
#           [ 0.3139,  0.4074,  0.6173],
#           [ 0.3349,  0.5943,  0.5797]],
#
#          [[-0.0409, -0.0555, -0.1679],
#           [ 0.0496, -0.1028, -0.1609],
#           [-0.1892, -0.1774, -0.0153]],
#
#          [[ 0.0428, -0.1369,  0.0255],
#           [-0.0210, -0.0985,  0.1046],
#           [-0.0562,  0.0859,  0.0974]]],
#
#
#         [[[ 0.6893,  0.5202,  0.6389],
#           [ 0.3904,  0.3991,  0.5056],
#           [ 0.4855,  0.5800,  0.6191]],
#
#          [[ 0.3042,  0.3213,  0.4066],
#           [ 0.2416,  0.1951,  0.3975],
#           [ 0.2434,  0.1513,  0.3992]],
#
#          [[ 0.1757, -0.0271, -0.1072],
#           [ 0.1259, -0.0414,  0.0578],
#           [-0.0669,  0.2698,  0.1323]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Who_mu
# tensor([[[[ 4.2960e-02, -1.8782e-02,  3.4331e-02],
#           [-3.7617e-01, -2.6454e-01, -3.5489e-01],
#           [-2.6716e-01,  2.9074e-02, -1.0423e-01]],
#
#          [[-4.6629e-01, -4.4109e-01,  1.7605e-01],
#           [-4.1722e-01, -3.2188e-01, -2.3315e-01],
#           [-3.6009e-01,  2.8799e-01,  5.8393e-01]],
#
#          [[-1.3392e+00,  2.5167e-01,  6.6726e-01],
#           [-8.2628e-01,  1.4399e-01, -6.3494e-01],
#           [-1.6277e-01, -4.5857e-01,  6.9736e-01]]],
#
#
#         [[[-2.0841e-02, -1.8111e-01, -2.4765e-02],
#           [ 1.4310e-02, -9.9407e-02, -2.0886e-01],
#           [-1.8029e-01, -2.0063e-01, -2.1434e-01]],
#
#          [[-3.2561e-02, -4.7475e-02, -1.6084e-01],
#           [-1.1912e-01, -4.5133e-02, -8.2083e-02],
#           [-2.4669e-01, -3.4841e-02, -2.6680e-01]],
#
#          [[-2.4766e-01,  1.8113e-01,  3.4192e-02],
#           [-3.7504e-01, -2.2193e-01, -1.3561e-01],
#           [-2.7016e-01, -2.1256e-01,  1.3686e-01]]],
#
#
#         [[[-3.9142e-01, -1.2422e-01, -2.0015e-01],
#           [-1.1786e-01, -1.9750e-01, -2.9472e-01],
#           [-2.5315e-01, -2.0551e-01, -9.7249e-02]],
#
#          [[-9.9875e-02, -2.4524e-01, -4.6238e-01],
#           [-1.1185e-01, -3.9753e-01, -3.6032e-01],
#           [-2.6651e-01, -2.0156e-01, -4.2616e-01]],
#
#          [[-1.5242e-01, -2.2463e-01, -1.2129e-05],
#           [ 1.0533e-02, -3.5005e-01, -4.8768e-01],
#           [ 1.0951e-01, -1.6355e-01, -2.4281e-02]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Wxi_bias
# tensor([0.0814, 0.1309, 0.0942], device='cuda:0')
# torch.Size([3])
# =========================
# cell0.Wxf_bias
# tensor([ 0.0134, -0.0948, -0.3745], device='cuda:0')
# torch.Size([3])
# =========================
# cell0.Wxc_bias
# tensor([-0.2399,  0.1520,  0.1440], device='cuda:0')
# torch.Size([3])
# =========================
# cell0.Wxo_bias
# tensor([0.1341, 0.0072, 0.2107], device='cuda:0')
# torch.Size([3])
# =========================
# cell0.Wxi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Whi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Wxf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Whf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Wxc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Whc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Wxo_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Who_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Wxi_mu
# tensor([[[[-0.0230,  0.0466, -0.0035],
#           [-0.1342, -0.3288,  0.0476],
#           [-0.1025, -0.2917, -0.2485]],
#
#          [[-0.4088, -0.2320, -0.4693],
#           [-0.1855, -0.3493, -0.2882],
#           [-0.5222, -0.3000, -0.4180]],
#
#          [[ 0.3004,  0.0048,  0.4431],
#           [ 0.1859, -0.0416,  0.1919],
#           [-0.9506, -1.1509, -0.5154]]],
#
#
#         [[[-0.3081, -0.0979,  0.0215],
#           [-0.1934, -0.3703, -0.0877],
#           [-0.0184, -0.2374, -0.2140]],
#
#          [[-0.7249, -0.3978, -0.5167],
#           [-0.5642, -0.3773, -0.2113],
#           [-0.3611, -0.1650, -0.1354]],
#
#          [[-0.2621, -0.3600, -0.2737],
#           [-0.3802,  0.1122, -0.1374],
#           [-0.6005,  0.0567, -0.0969]]]], device='cuda:0')
# torch.Size([2, 3, 3, 3])
# =========================
# cell1.Whi_mu
# tensor([[[[-0.2599, -0.2471, -0.0116],
#           [-0.0359, -0.1602, -0.2456],
#           [-0.2524, -0.2631, -0.1373]],
#
#          [[-0.2223, -0.0630, -0.3129],
#           [ 0.1684,  0.2002, -0.1615],
#           [ 0.0063,  0.1030,  0.1251]]],
#
#
#         [[[-0.0649, -0.0351, -0.3270],
#           [-0.4118, -0.2165, -0.0317],
#           [-0.1581,  0.1536,  0.0669]],
#
#          [[-0.1150, -0.2266, -0.2423],
#           [-0.2006,  0.2029, -0.0150],
#           [-0.0281, -0.0202,  0.1173]]]], device='cuda:0')
# torch.Size([2, 2, 3, 3])
# =========================
# cell1.Wxf_mu
# tensor([[[[ 0.2271,  0.0177,  0.0970],
#           [ 0.2124,  0.0111,  0.1750],
#           [ 0.2087,  0.1379,  0.2247]],
#
#          [[-0.0665, -0.2313, -0.0773],
#           [-0.0363, -0.2852, -0.0278],
#           [ 0.1338, -0.1602,  0.2575]],
#
#          [[ 0.4393, -0.1570,  0.1656],
#           [-0.0135,  0.0504,  0.1961],
#           [ 0.2666,  0.0865,  0.4987]]],
#
#
#         [[[ 0.1147,  0.0706,  0.2466],
#           [-0.0909,  0.0737,  0.0499],
#           [ 0.1154,  0.1244,  0.1006]],
#
#          [[-0.2593,  0.1307, -0.4280],
#           [-0.1966, -0.1842,  0.0765],
#           [ 0.2303,  0.1559, -0.1207]],
#
#          [[ 0.3023, -0.2362, -0.0082],
#           [-0.1752, -0.1896, -0.0508],
#           [-0.7265,  0.4676, -0.0972]]]], device='cuda:0')
# torch.Size([2, 3, 3, 3])
# =========================
# cell1.Whf_mu
# tensor([[[[-0.0050, -0.1508,  0.0982],
#           [ 0.2273, -0.1300, -0.1574],
#           [-0.1182,  0.0278, -0.1470]],
#
#          [[ 0.2029,  0.0716, -0.1574],
#           [-0.1065,  0.0980, -0.2075],
#           [-0.0340,  0.1039,  0.1417]]],
#
#
#         [[[ 0.4104,  0.1398, -0.1097],
#           [ 0.2717, -0.0932,  0.1196],
#           [ 0.2818,  0.3693,  0.3636]],
#
#          [[-0.4093, -0.3568, -0.2878],
#           [-0.1270, -0.1954, -0.0195],
#           [-0.1502,  0.1416,  0.0186]]]], device='cuda:0')
# torch.Size([2, 2, 3, 3])
# =========================
# cell1.Wxc_mu
# tensor([[[[ 0.1311, -0.1579, -0.0893],
#           [-0.1369, -0.0413, -0.1152],
#           [ 0.1115,  0.0096,  0.0128]],
#
#          [[-0.0321,  0.0596,  0.2334],
#           [ 0.1119,  0.4477,  0.2386],
#           [ 0.1429,  0.3463, -0.0642]],
#
#          [[-0.1662,  0.4114, -0.1700],
#           [ 0.1268,  0.0444, -0.0037],
#           [ 0.5892,  0.8325,  0.1635]]],
#
#
#         [[[ 0.1256,  0.0563,  0.2004],
#           [-0.0175, -0.1037, -0.0476],
#           [ 0.2199,  0.1425,  0.2119]],
#
#          [[ 0.0552, -0.5350,  0.0430],
#           [-0.2111, -0.4868, -0.3019],
#           [-0.2745, -0.0128,  0.2637]],
#
#          [[-0.2361,  0.4779, -0.1536],
#           [-0.1088,  0.1051, -0.0256],
#           [-0.3173, -0.3641,  0.0634]]]], device='cuda:0')
# torch.Size([2, 3, 3, 3])
# =========================
# cell1.Whc_mu
# tensor([[[[ 0.1160,  0.0482,  0.1377],
#           [-0.0470,  0.0136, -0.1136],
#           [-0.0874,  0.1289, -0.0385]],
#
#          [[-0.0085,  0.0890,  0.0140],
#           [ 0.1578,  0.0026,  0.1002],
#           [-0.1523, -0.0213, -0.0998]]],
#
#
#         [[[ 0.2214,  0.2761,  0.2161],
#           [ 0.2073,  0.1390,  0.0914],
#           [ 0.1246,  0.1485,  0.1491]],
#
#          [[-0.0073,  0.0287,  0.0333],
#           [-0.0947, -0.3660, -0.0128],
#           [ 0.0494, -0.1545,  0.1584]]]], device='cuda:0')
# torch.Size([2, 2, 3, 3])
# =========================
# cell1.Wxo_mu
# tensor([[[[ 0.0822,  0.1102,  0.1202],
#           [ 0.0527, -0.3006,  0.0444],
#           [-0.1792,  0.0051,  0.0782]],
#
#          [[-0.1164, -0.1980, -0.2210],
#           [-0.0488, -0.2474, -0.3208],
#           [-0.0128, -0.3469,  0.0494]],
#
#          [[ 0.1810, -0.7069,  0.1492],
#           [ 0.0196,  0.1685,  0.7676],
#           [ 0.0408, -0.8269,  0.1767]]],
#
#
#         [[[-0.0922, -0.1962, -0.1657],
#           [-0.3513, -0.0763, -0.1353],
#           [-0.3328, -0.1116, -0.1919]],
#
#          [[-0.6429, -0.4590, -0.3655],
#           [-0.3234, -0.5031, -0.2389],
#           [-0.3423, -0.1017, -0.0550]],
#
#          [[-0.3882, -0.2876, -0.5897],
#           [-0.2182,  0.3292,  0.1633],
#           [-0.4553,  0.3573,  0.0255]]]], device='cuda:0')
# torch.Size([2, 3, 3, 3])
# =========================
# cell1.Who_mu
# tensor([[[[-0.0537, -0.2184, -0.1960],
#           [ 0.0793, -0.0469,  0.1047],
#           [-0.1044,  0.0407,  0.2452]],
#
#          [[ 0.2056, -0.0212, -0.0146],
#           [-0.1184, -0.0156, -0.1892],
#           [ 0.0634,  0.0955, -0.0668]]],
#
#
#         [[[-0.5748, -0.0220, -0.2701],
#           [-0.4534, -0.1483, -0.1806],
#           [-0.0301, -0.2486,  0.0256]],
#
#          [[-0.3560, -0.2396, -0.0017],
#           [ 0.0394, -0.2146,  0.1541],
#           [ 0.0102, -0.1503,  0.0513]]]], device='cuda:0')
# torch.Size([2, 2, 3, 3])
# =========================
# cell1.Wxi_bias
# tensor([0.1796, 0.3558], device='cuda:0')
# torch.Size([2])
# =========================
# cell1.Wxf_bias
# tensor([-0.1626, -0.0935], device='cuda:0')
# torch.Size([2])
# =========================
# cell1.Wxc_bias
# tensor([-0.1765,  0.1234], device='cuda:0')
# torch.Size([2])
# =========================
# cell1.Wxo_bias
# tensor([ 0.3058, -0.0363], device='cuda:0')
# torch.Size([2])
# =========================
# cell1.Wxi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Whi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Wxf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Whf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Wxc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Whc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Wxo_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Who_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Wxi_mu
# tensor([[[[-0.6423, -0.3906, -0.1379],
#           [-1.1632, -0.6641, -0.7773],
#           [-0.5520, -0.0763, -0.2624]],
#
#          [[ 0.2504,  0.3180,  0.4318],
#           [ 0.6036,  1.3772,  0.1379],
#           [-0.0039,  0.0772,  0.0623]]]], device='cuda:0')
# torch.Size([1, 2, 3, 3])
# =========================
# cell2.Whi_mu
# tensor([[[[-0.0863, -0.4658, -0.3794],
#           [-0.3827, -0.0875, -0.5075],
#           [ 0.0129, -0.1447,  0.2190]]]], device='cuda:0')
# torch.Size([1, 1, 3, 3])
# =========================
# cell2.Wxf_mu
# tensor([[[[ 0.0266,  0.0258,  0.0367],
#           [-0.3121, -0.1775, -0.0122],
#           [ 0.2625,  0.2606,  0.0774]],
#
#          [[-0.0209,  0.1912,  0.1674],
#           [ 0.3926,  0.8309,  0.1411],
#           [ 0.1646,  0.0113, -0.2837]]]], device='cuda:0')
# torch.Size([1, 2, 3, 3])
# =========================
# cell2.Whf_mu
# tensor([[[[ 0.3847, -0.0420,  0.2152],
#           [-0.2059,  0.1114, -0.0909],
#           [-0.2933,  0.1623,  0.3783]]]], device='cuda:0')
# torch.Size([1, 1, 3, 3])
# =========================
# cell2.Wxc_mu
# tensor([[[[-0.0833, -0.2570,  0.1175],
#           [-0.5897, -0.3605, -0.2642],
#           [ 0.0161,  0.1338, -0.0336]],
#
#          [[-0.0422, -0.1120,  0.0646],
#           [ 0.1847,  0.9165, -0.1244],
#           [-0.0860, -0.0492, -0.1583]]]], device='cuda:0')
# torch.Size([1, 2, 3, 3])
# =========================
# cell2.Whc_mu
# tensor([[[[-0.0504, -0.0648, -0.1043],
#           [-0.0942, -0.1594, -0.0390],
#           [ 0.0510, -0.0974, -0.0302]]]], device='cuda:0')
# torch.Size([1, 1, 3, 3])
# =========================
# cell2.Wxo_mu
# tensor([[[[-0.7113, -0.3272, -0.2529],
#           [-0.9133, -0.6301, -0.4213],
#           [ 0.0056,  0.2432, -0.0953]],
#
#          [[-0.2234, -0.0975,  0.0768],
#           [ 0.2590,  0.9676, -0.1638],
#           [ 0.0367,  0.2603, -0.0561]]]], device='cuda:0')
# torch.Size([1, 2, 3, 3])
# =========================
# cell2.Who_mu
# tensor([[[[-0.3425,  0.1325, -0.1561],
#           [ 0.3030,  0.1554,  0.3414],
#           [ 0.4759, -0.1258, -0.3464]]]], device='cuda:0')
# torch.Size([1, 1, 3, 3])
# =========================
# cell2.Wxi_bias
# tensor([-0.0115], device='cuda:0')
# torch.Size([1])
# =========================
# cell2.Wxf_bias
# tensor([-0.8602], device='cuda:0')
# torch.Size([1])
# =========================
# cell2.Wxc_bias
# tensor([0.0313], device='cuda:0')
# torch.Size([1])
# =========================
# cell2.Wxo_bias
# tensor([-0.0644], device='cuda:0')
# torch.Size([1])
# =========================
# cell2.Wxi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Whi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Wxf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Whf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Wxc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Whc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Wxo_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Who_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================

# %%
    print ('*******************  initialize BayesConvLSTM without given weight  *********************')
    # initialize our model
    model = dlacs.BayesConvLSTM.BayesConvLSTM(input_channels, hidden_channels, kernel_size,
                                              cell_type='reduced').to(device)
# Out:
# *******************  initialize BayesConvLSTM without given weight  *********************
# !@#$% The network will be built with reduced size BayesConvLSTM cell. !@#$%

# %%
    print ('*******************  check wieght matrix of BayesConvLSTM  *********************')
    for name, param in model.named_parameters():
        if param.requires_grad:
            print (name)
            print (param.data)
            print (param.size())
            print ("=========================")
# Out:
# *******************  check wieght matrix of BayesConvLSTM  *********************
# cell0.Wxi_mu
# tensor([[[[-0.1158,  0.0129,  0.0481],
#           [ 0.0608,  0.0715, -0.0874],
#           [-0.1035, -0.1617, -0.0581]],
#
#          [[ 0.0543, -0.0250,  0.1098],
#           [-0.1377,  0.0978,  0.0605],
#           [-0.0510, -0.1285, -0.0766]],
#
#          [[-0.0895,  0.0918,  0.0301],
#           [-0.0995, -0.1500,  0.0362],
#           [ 0.0097, -0.1787, -0.1635]]],
#
#
#         [[[-0.0810, -0.0577, -0.1446],
#           [-0.0884,  0.0724, -0.0906],
#           [-0.1643,  0.0764, -0.1874]],
#
#          [[ 0.0952,  0.1273,  0.1606],
#           [-0.1033, -0.1635, -0.0726],
#           [-0.0171,  0.1902, -0.0164]],
#
#          [[ 0.1215,  0.0172, -0.0715],
#           [-0.0475,  0.1481,  0.0047],
#           [-0.0927,  0.0123, -0.1857]]],
#
#
#         [[[-0.0844,  0.0875, -0.1109],
#           [ 0.0819, -0.0614,  0.1107],
#           [ 0.0112, -0.1909,  0.1020]],
#
#          [[-0.1142, -0.1211,  0.1153],
#           [ 0.1138, -0.1216,  0.0206],
#           [ 0.1008, -0.1316,  0.1094]],
#
#          [[-0.0296, -0.1181, -0.0442],
#           [ 0.1183,  0.1212,  0.1492],
#           [ 0.1335,  0.1144,  0.0352]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Whi_mu
# tensor([[[[ 0.0188,  0.1666, -0.1311],
#           [ 0.0526,  0.0481, -0.0843],
#           [-0.1047, -0.0571,  0.1648]],
#
#          [[-0.0287, -0.1200,  0.0346],
#           [ 0.1816, -0.0139, -0.0506],
#           [ 0.0113,  0.0561, -0.0689]],
#
#          [[ 0.1548,  0.1548, -0.0694],
#           [-0.0549, -0.1030, -0.0353],
#           [-0.0808,  0.0978, -0.1863]]],
#
#
#         [[[ 0.1803,  0.1433,  0.0828],
#           [-0.1138,  0.1754, -0.0739],
#           [ 0.1875,  0.0956, -0.1228]],
#
#          [[-0.1145,  0.0648, -0.1177],
#           [ 0.1769, -0.0474, -0.1027],
#           [ 0.1834,  0.0949,  0.0423]],
#
#          [[-0.1704, -0.1322, -0.1067],
#           [ 0.0642,  0.1818,  0.0103],
#           [-0.1459, -0.0602, -0.1551]]],
#
#
#         [[[-0.0707,  0.1699,  0.1447],
#           [ 0.1125, -0.1911, -0.1228],
#           [-0.1173, -0.1058,  0.0588]],
#
#          [[-0.0281, -0.0598,  0.0414],
#           [ 0.0205, -0.0419,  0.0688],
#           [ 0.1059, -0.0291,  0.0268]],
#
#          [[ 0.0491,  0.0844, -0.1218],
#           [ 0.1541,  0.0443,  0.1659],
#           [ 0.1139,  0.0401, -0.0259]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Wxf_mu
# tensor([[[[-0.0573,  0.0432,  0.1424],
#           [ 0.1170,  0.1495, -0.0643],
#           [ 0.0825, -0.0436, -0.1585]],
#
#          [[ 0.1454, -0.1670, -0.0655],
#           [-0.1703,  0.1384, -0.1791],
#           [-0.1585, -0.0879,  0.1506]],
#
#          [[-0.1042, -0.1557,  0.1183],
#           [-0.1462,  0.0546,  0.0673],
#           [-0.1463,  0.1759,  0.1688]]],
#
#
#         [[[ 0.0905,  0.0666,  0.1109],
#           [-0.1600,  0.1793, -0.0843],
#           [-0.1363,  0.0107, -0.1824]],
#
#          [[-0.1777,  0.1359, -0.0964],
#           [ 0.0044, -0.0575, -0.0036],
#           [-0.1141, -0.1773,  0.1014]],
#
#          [[-0.1315,  0.0732,  0.0888],
#           [ 0.1612,  0.0229,  0.0610],
#           [ 0.1603, -0.1836,  0.1660]]],
#
#
#         [[[-0.0082,  0.1479,  0.1113],
#           [ 0.0226,  0.0042, -0.0506],
#           [-0.1392,  0.0796,  0.0148]],
#
#          [[-0.0802,  0.1883,  0.1742],
#           [-0.1730,  0.1736, -0.0778],
#           [ 0.0573, -0.1307,  0.0937]],
#
#          [[ 0.0472,  0.0562,  0.1525],
#           [ 0.1742,  0.1449, -0.0984],
#           [ 0.0785, -0.1539, -0.0094]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Whf_mu
# tensor([[[[-0.1599, -0.0107,  0.0353],
#           [-0.1423,  0.0929,  0.0857],
#           [-0.1136,  0.1297,  0.0004]],
#
#          [[ 0.1140,  0.1214, -0.0659],
#           [-0.1851,  0.0704, -0.0564],
#           [ 0.0987,  0.0644, -0.1020]],
#
#          [[-0.1531, -0.1223,  0.0585],
#           [-0.0543, -0.0536, -0.0166],
#           [ 0.0420,  0.0207,  0.0637]]],
#
#
#         [[[-0.0916,  0.0460, -0.0376],
#           [-0.1023,  0.0820,  0.1385],
#           [-0.0922, -0.1395, -0.0860]],
#
#          [[ 0.0378, -0.0011, -0.1315],
#           [ 0.0419,  0.0625,  0.1795],
#           [-0.0914,  0.1140, -0.0182]],
#
#          [[ 0.0576, -0.1897,  0.1304],
#           [ 0.1452, -0.1011,  0.0127],
#           [ 0.0071, -0.1287,  0.0458]]],
#
#
#         [[[-0.1664, -0.1493,  0.1239],
#           [-0.0821,  0.0225,  0.0488],
#           [-0.1183,  0.0849, -0.0205]],
#
#          [[-0.1721, -0.1594, -0.0229],
#           [-0.1255,  0.1825, -0.1591],
#           [ 0.1226,  0.0679,  0.0376]],
#
#          [[ 0.0294, -0.1342, -0.0263],
#           [-0.1461, -0.0714, -0.0378],
#           [-0.1616,  0.1333, -0.1495]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Wxc_mu
# tensor([[[[-0.0758,  0.1776, -0.1380],
#           [ 0.0807, -0.0035, -0.1048],
#           [-0.0845, -0.0717, -0.0854]],
#
#          [[-0.1016, -0.1002, -0.0642],
#           [ 0.0424,  0.0847,  0.1771],
#           [ 0.1674, -0.0862,  0.1558]],
#
#          [[ 0.1573,  0.1765, -0.1018],
#           [-0.0803, -0.0462, -0.1500],
#           [ 0.0614,  0.1365, -0.0235]]],
#
#
#         [[[-0.1300, -0.1838, -0.1377],
#           [ 0.1038,  0.0398, -0.1090],
#           [ 0.0856, -0.0108,  0.0796]],
#
#          [[ 0.1881,  0.1462,  0.1813],
#           [-0.0307,  0.1492,  0.1428],
#           [-0.1342, -0.1698, -0.0133]],
#
#          [[-0.0014, -0.0553, -0.1600],
#           [-0.1531, -0.0311, -0.0344],
#           [-0.0421, -0.1533,  0.1224]]],
#
#
#         [[[-0.1040,  0.0529, -0.1490],
#           [-0.1275,  0.1378,  0.0294],
#           [ 0.0535, -0.1814,  0.0440]],
#
#          [[ 0.1700,  0.1836, -0.1640],
#           [ 0.1499, -0.1341, -0.0633],
#           [-0.0069, -0.1212, -0.0507]],
#
#          [[ 0.1608, -0.0725, -0.0691],
#           [-0.1835, -0.0926,  0.1092],
#           [ 0.0401,  0.0797, -0.0101]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Whc_mu
# tensor([[[[ 0.1365, -0.0140, -0.1018],
#           [ 0.0790, -0.1302,  0.0844],
#           [-0.1151,  0.0146,  0.1716]],
#
#          [[ 0.0356,  0.0281,  0.0894],
#           [ 0.1367, -0.1470, -0.1522],
#           [-0.0316,  0.1590,  0.1766]],
#
#          [[ 0.0413, -0.1659,  0.1171],
#           [-0.1746, -0.0930, -0.1331],
#           [ 0.1376, -0.1158, -0.1449]]],
#
#
#         [[[ 0.0050,  0.0087,  0.1074],
#           [ 0.1366,  0.1533, -0.0672],
#           [-0.1020,  0.0626, -0.0441]],
#
#          [[ 0.0326,  0.0370,  0.1104],
#           [-0.1844, -0.0349, -0.1345],
#           [-0.0562, -0.1579, -0.0810]],
#
#          [[ 0.0163,  0.1432, -0.0197],
#           [-0.0484, -0.0098,  0.1541],
#           [ 0.1497,  0.1313,  0.0682]]],
#
#
#         [[[ 0.1727,  0.0168, -0.0482],
#           [-0.1370,  0.1378,  0.0808],
#           [-0.0588,  0.0080,  0.1461]],
#
#          [[ 0.1133, -0.0546,  0.0131],
#           [-0.1865, -0.0409, -0.1114],
#           [-0.1894, -0.0495,  0.1915]],
#
#          [[ 0.0788,  0.0702,  0.1916],
#           [-0.1294, -0.1835, -0.1580],
#           [ 0.1723, -0.1230,  0.0176]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Wxo_mu
# tensor([[[[ 0.1282,  0.0241,  0.1371],
#           [-0.1723,  0.1343, -0.0788],
#           [ 0.0959, -0.1495, -0.1317]],
#
#          [[-0.0686,  0.1120, -0.0914],
#           [ 0.0742,  0.0645,  0.1591],
#           [-0.0865,  0.0724, -0.0046]],
#
#          [[-0.0213,  0.0896, -0.0862],
#           [-0.0718, -0.1860,  0.1282],
#           [-0.1755, -0.0091,  0.0772]]],
#
#
#         [[[ 0.1336, -0.1739,  0.1141],
#           [-0.0680, -0.1043,  0.1136],
#           [ 0.0562,  0.0251,  0.1255]],
#
#          [[-0.1892, -0.1564, -0.1731],
#           [-0.0211, -0.0797,  0.0692],
#           [-0.1044,  0.1888,  0.0347]],
#
#          [[-0.1717,  0.1043,  0.1074],
#           [-0.0085, -0.0737, -0.1207],
#           [ 0.0245, -0.1033, -0.0683]]],
#
#
#         [[[-0.1637, -0.1081, -0.1393],
#           [-0.1500,  0.0307,  0.0378],
#           [ 0.0495,  0.1760, -0.0319]],
#
#          [[ 0.1705, -0.0488, -0.1091],
#           [ 0.1335,  0.0209, -0.1256],
#           [-0.1701, -0.0343,  0.1028]],
#
#          [[ 0.1248,  0.0593,  0.0671],
#           [ 0.0862, -0.0467,  0.0371],
#           [ 0.0106, -0.1623, -0.1590]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Who_mu
# tensor([[[[ 0.1462, -0.0596,  0.1304],
#           [-0.1829, -0.0371,  0.0721],
#           [ 0.1151, -0.0044, -0.0196]],
#
#          [[ 0.1118,  0.1432,  0.1801],
#           [-0.1617,  0.1520,  0.0354],
#           [-0.0399, -0.0475, -0.1526]],
#
#          [[-0.1864,  0.0102,  0.0997],
#           [-0.1683,  0.0095,  0.1147],
#           [-0.0404,  0.0273,  0.1837]]],
#
#
#         [[[-0.0359, -0.1813, -0.1639],
#           [ 0.0576,  0.0400, -0.0090],
#           [ 0.0822, -0.1179, -0.0170]],
#
#          [[ 0.1498,  0.0260, -0.1795],
#           [-0.1244, -0.0594, -0.0917],
#           [-0.1016,  0.1586, -0.1525]],
#
#          [[-0.1539, -0.1305, -0.1040],
#           [-0.1914, -0.0598, -0.1557],
#           [ 0.0599,  0.1333, -0.1027]]],
#
#
#         [[[-0.1562,  0.1048,  0.1839],
#           [-0.0204,  0.0091, -0.1186],
#           [-0.0302, -0.0018,  0.1656]],
#
#          [[-0.1892, -0.0673,  0.1475],
#           [ 0.1444,  0.0676,  0.0438],
#           [ 0.0177,  0.1792,  0.0814]],
#
#          [[-0.0884,  0.1047, -0.1301],
#           [-0.0068,  0.1738,  0.0405],
#           [ 0.0381, -0.0663,  0.0932]]]], device='cuda:0')
# torch.Size([3, 3, 3, 3])
# =========================
# cell0.Wxi_bias
# tensor([0.0407, 0.0576, 0.1167], device='cuda:0')
# torch.Size([3])
# =========================
# cell0.Wxf_bias
# tensor([ 0.0277, -0.1467,  0.1489], device='cuda:0')
# torch.Size([3])
# =========================
# cell0.Wxc_bias
# tensor([-0.0696, -0.1003, -0.1896], device='cuda:0')
# torch.Size([3])
# =========================
# cell0.Wxo_bias
# tensor([-0.1390, -0.0224,  0.1105], device='cuda:0')
# torch.Size([3])
# =========================
# cell0.Wxi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Whi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Wxf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Whf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Wxc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Whc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Wxo_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell0.Who_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Wxi_mu
# tensor([[[[ 0.1470,  0.1126,  0.1757],
#           [-0.0658, -0.0666, -0.1322],
#           [ 0.1611, -0.0567,  0.0472]],
#
#          [[ 0.1483,  0.1581,  0.0884],
#           [-0.1853,  0.1110, -0.1297],
#           [-0.0807,  0.1099,  0.1623]],
#
#          [[ 0.0798,  0.1868, -0.0031],
#           [-0.1008, -0.1095, -0.0499],
#           [ 0.0637, -0.1135,  0.1589]]],
#
#
#         [[[-0.0608, -0.0058,  0.1193],
#           [-0.0569,  0.0586, -0.0070],
#           [ 0.0058,  0.0481,  0.0208]],
#
#          [[ 0.1026,  0.0474, -0.1172],
#           [ 0.0020, -0.0937,  0.0051],
#           [-0.1036,  0.0775, -0.0443]],
#
#          [[ 0.0914,  0.1123,  0.1424],
#           [ 0.1500,  0.1280,  0.0765],
#           [ 0.0020, -0.0508, -0.1519]]]], device='cuda:0')
# torch.Size([2, 3, 3, 3])
# =========================
# cell1.Whi_mu
# tensor([[[[-0.0789, -0.1536, -0.0187],
#           [-0.0927, -0.0370,  0.0957],
#           [-0.0804,  0.1596,  0.0641]],
#
#          [[-0.0889,  0.0274, -0.0230],
#           [-0.1288, -0.0302, -0.1669],
#           [ 0.1339,  0.0297, -0.1217]]],
#
#
#         [[[-0.0334, -0.0856,  0.1486],
#           [ 0.1208, -0.0072, -0.1152],
#           [-0.1707, -0.0389,  0.1657]],
#
#          [[-0.1330, -0.0844, -0.0116],
#           [ 0.1020, -0.0075,  0.1372],
#           [ 0.0356,  0.1612, -0.1368]]]], device='cuda:0')
# torch.Size([2, 2, 3, 3])
# =========================
# cell1.Wxf_mu
# tensor([[[[-0.1329, -0.1570, -0.0736],
#           [-0.1141,  0.0230,  0.0376],
#           [ 0.0930, -0.0198, -0.1505]],
#
#          [[ 0.1729,  0.0686, -0.0803],
#           [ 0.1116, -0.0164,  0.1606],
#           [-0.1192,  0.1759,  0.0532]],
#
#          [[ 0.0469, -0.0943,  0.0611],
#           [-0.0280, -0.1164, -0.0029],
#           [ 0.1105, -0.0970, -0.0895]]],
#
#
#         [[[-0.0613,  0.0742, -0.0138],
#           [-0.1811,  0.0061,  0.1386],
#           [-0.0676, -0.0864,  0.1464]],
#
#          [[ 0.1708,  0.0300,  0.1553],
#           [ 0.0686,  0.0355,  0.1252],
#           [-0.1316,  0.0550,  0.1314]],
#
#          [[-0.0531, -0.1658,  0.0350],
#           [ 0.1130, -0.1102,  0.0561],
#           [-0.0232,  0.1732, -0.0213]]]], device='cuda:0')
# torch.Size([2, 3, 3, 3])
# =========================
# cell1.Whf_mu
# tensor([[[[ 0.0195, -0.1781, -0.1381],
#           [-0.1837,  0.0965,  0.1363],
#           [ 0.0606, -0.1177,  0.0270]],
#
#          [[-0.0754,  0.1732,  0.1811],
#           [-0.0698,  0.1757, -0.1527],
#           [ 0.1910, -0.0913,  0.1812]]],
#
#
#         [[[ 0.1302,  0.0672, -0.0518],
#           [ 0.1569, -0.0362, -0.0198],
#           [ 0.1357, -0.0526,  0.0465]],
#
#          [[-0.1684, -0.0660, -0.0546],
#           [ 0.0793, -0.1482, -0.0102],
#           [-0.1231,  0.0147,  0.1288]]]], device='cuda:0')
# torch.Size([2, 2, 3, 3])
# =========================
# cell1.Wxc_mu
# tensor([[[[-0.1253, -0.1069, -0.1876],
#           [ 0.1274, -0.1070, -0.1563],
#           [ 0.1636, -0.1434,  0.1148]],
#
#          [[ 0.1657, -0.0511,  0.1228],
#           [ 0.0383,  0.1007, -0.0880],
#           [-0.0250, -0.1219, -0.1068]],
#
#          [[ 0.1718,  0.0473, -0.0908],
#           [ 0.0174, -0.0176,  0.1104],
#           [ 0.0761, -0.0813, -0.0037]]],
#
#
#         [[[ 0.1709, -0.1494, -0.0714],
#           [-0.1143,  0.0509, -0.0399],
#           [ 0.0573, -0.1336, -0.1370]],
#
#          [[ 0.0547,  0.1194, -0.0674],
#           [ 0.1862, -0.1140,  0.1230],
#           [-0.1444, -0.0965, -0.0615]],
#
#          [[ 0.0972, -0.0672, -0.0744],
#           [ 0.1437,  0.1914, -0.0394],
#           [-0.0631,  0.1872,  0.1846]]]], device='cuda:0')
# torch.Size([2, 3, 3, 3])
# =========================
# cell1.Whc_mu
# tensor([[[[ 0.1178,  0.0667,  0.1363],
#           [-0.0189,  0.1438,  0.0669],
#           [-0.1556,  0.1218, -0.1193]],
#
#          [[ 0.1118,  0.1129, -0.0644],
#           [-0.0177, -0.1300,  0.0603],
#           [ 0.0401, -0.0833, -0.1455]]],
#
#
#         [[[ 0.0422, -0.0500, -0.0470],
#           [ 0.1742, -0.1518,  0.1051],
#           [ 0.0264, -0.0366,  0.0556]],
#
#          [[-0.1816,  0.1785,  0.1367],
#           [ 0.0278, -0.1661,  0.1918],
#           [ 0.0419, -0.0051,  0.0969]]]], device='cuda:0')
# torch.Size([2, 2, 3, 3])
# =========================
# cell1.Wxo_mu
# tensor([[[[ 0.1286, -0.1188, -0.1745],
#           [-0.1172, -0.1592,  0.0292],
#           [-0.0849,  0.0165, -0.1099]],
#
#          [[-0.0003, -0.0549,  0.1291],
#           [ 0.0694, -0.0448,  0.0684],
#           [-0.1376,  0.1311,  0.0510]],
#
#          [[-0.1553, -0.1442,  0.0007],
#           [ 0.0667, -0.0246, -0.0395],
#           [ 0.1488,  0.0449,  0.1024]]],
#
#
#         [[[ 0.1110,  0.1549, -0.0973],
#           [-0.1252, -0.0235, -0.1306],
#           [ 0.1023, -0.0529,  0.0490]],
#
#          [[-0.0257, -0.1527, -0.1215],
#           [-0.0154, -0.0156,  0.1416],
#           [ 0.1547, -0.0488, -0.1850]],
#
#          [[ 0.1393, -0.0467,  0.0698],
#           [ 0.0501,  0.0055, -0.1695],
#           [-0.0110,  0.0406, -0.1033]]]], device='cuda:0')
# torch.Size([2, 3, 3, 3])
# =========================
# cell1.Who_mu
# tensor([[[[-0.0607,  0.0070, -0.1178],
#           [-0.1571,  0.0992,  0.0837],
#           [-0.0967,  0.0202, -0.0624]],
#
#          [[-0.0922, -0.1188, -0.1036],
#           [-0.1808,  0.0641, -0.1192],
#           [-0.1602, -0.0873, -0.0955]]],
#
#
#         [[[-0.0106,  0.1336, -0.0010],
#           [ 0.0686, -0.1538, -0.1527],
#           [-0.1511,  0.0504, -0.0755]],
#
#          [[ 0.0388, -0.0395,  0.1436],
#           [-0.0528, -0.1334,  0.0381],
#           [-0.1796,  0.0024,  0.1051]]]], device='cuda:0')
# torch.Size([2, 2, 3, 3])
# =========================
# cell1.Wxi_bias
# tensor([0.0825, 0.1220], device='cuda:0')
# torch.Size([2])
# =========================
# cell1.Wxf_bias
# tensor([0.0942, 0.0219], device='cuda:0')
# torch.Size([2])
# =========================
# cell1.Wxc_bias
# tensor([ 0.1152, -0.0965], device='cuda:0')
# torch.Size([2])
# =========================
# cell1.Wxo_bias
# tensor([0.1872, 0.0731], device='cuda:0')
# torch.Size([2])
# =========================
# cell1.Wxi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Whi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Wxf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Whf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Wxc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Whc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Wxo_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell1.Who_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Wxi_mu
# tensor([[[[-0.2281, -0.0217,  0.1464],
#           [ 0.1174, -0.2113, -0.0480],
#           [ 0.0385,  0.1023, -0.1963]],
#
#          [[-0.1539,  0.0242, -0.1635],
#           [-0.1631, -0.0034,  0.1180],
#           [ 0.2111, -0.1483, -0.2328]]]], device='cuda:0')
# torch.Size([1, 2, 3, 3])
# =========================
# cell2.Whi_mu
# tensor([[[[ 0.1964, -0.0346, -0.0650],
#           [-0.1397, -0.1415, -0.0377],
#           [-0.0421,  0.1149,  0.1946]]]], device='cuda:0')
# torch.Size([1, 1, 3, 3])
# =========================
# cell2.Wxf_mu
# tensor([[[[-0.2191,  0.0403, -0.0096],
#           [ 0.1962,  0.1728, -0.1798],
#           [ 0.0986,  0.0368, -0.1892]],
#
#          [[-0.0552,  0.1670, -0.1704],
#           [-0.1925, -0.0499, -0.0533],
#           [-0.0094, -0.1675,  0.2103]]]], device='cuda:0')
# torch.Size([1, 2, 3, 3])
# =========================
# cell2.Whf_mu
# tensor([[[[-0.0394, -0.0498,  0.1597],
#           [-0.1134,  0.1273, -0.0051],
#           [-0.0599, -0.0751,  0.0143]]]], device='cuda:0')
# torch.Size([1, 1, 3, 3])
# =========================
# cell2.Wxc_mu
# tensor([[[[ 0.2193, -0.0272,  0.2299],
#           [ 0.1263,  0.0688,  0.2171],
#           [-0.1998, -0.1796,  0.0365]],
#
#          [[-0.0649, -0.1985,  0.1304],
#           [ 0.1508, -0.0981, -0.0591],
#           [ 0.1902, -0.0772, -0.1249]]]], device='cuda:0')
# torch.Size([1, 2, 3, 3])
# =========================
# cell2.Whc_mu
# tensor([[[[ 0.0459, -0.1069, -0.1362],
#           [-0.1652,  0.1244, -0.0236],
#           [-0.1651, -0.0386,  0.2263]]]], device='cuda:0')
# torch.Size([1, 1, 3, 3])
# =========================
# cell2.Wxo_mu
# tensor([[[[-0.0579,  0.2025,  0.1603],
#           [ 0.0455,  0.1342, -0.2113],
#           [ 0.1309,  0.2212,  0.2232]],
#
#          [[ 0.2104, -0.2127,  0.1296],
#           [ 0.0763,  0.1349,  0.0159],
#           [ 0.0765,  0.0499, -0.1052]]]], device='cuda:0')
# torch.Size([1, 2, 3, 3])
# =========================
# cell2.Who_mu
# tensor([[[[-0.0229,  0.0098, -0.0374],
#           [ 0.1190,  0.2068,  0.1050],
#           [ 0.2353,  0.1688, -0.1166]]]], device='cuda:0')
# torch.Size([1, 1, 3, 3])
# =========================
# cell2.Wxi_bias
# tensor([-0.2273], device='cuda:0')
# torch.Size([1])
# =========================
# cell2.Wxf_bias
# tensor([0.1854], device='cuda:0')
# torch.Size([1])
# =========================
# cell2.Wxc_bias
# tensor([0.2204], device='cuda:0')
# torch.Size([1])
# =========================
# cell2.Wxo_bias
# tensor([0.0902], device='cuda:0')
# torch.Size([1])
# =========================
# cell2.Wxi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Whi_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Wxf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Whf_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Wxc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Whc_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Wxo_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
# cell2.Who_log_alpha
# tensor([[-3.]], device='cuda:0')
# torch.Size([1, 1])
# =========================
