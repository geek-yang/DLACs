# %% [markdown]
# # Copyright Netherlands eScience Center <br>
# ** Function     : Test BayesConvLSTM module ** <br>
# ** Author       : Yang Liu ** <br>
# ** First Built  : 2020.03.02 ** <br>
# ** Last Update  : 2020.03.02 ** <br>
# ** Library      : Pytorth, os, dlacs. **<br>
# Description     : This notebook serves to unittest the BayesConvLSTM module in DLACs. <br>
# <br>
# Return Values   : Time series and figures <br>

# %%
# %matplotlib inline

import sys
# for data loading
import os
#import scipy
import torch
import torch.nn.functional

#sys.path.append(os.path.join('C:','Users','nosta','ML4Climate','Scripts','DLACs'))
#sys.path.append("C:\\Users\\nosta\\ML4Climate\\Scripts\\DLACs")
sys.path.append("../../DLACs")
import dlacs
import dlacs.BayesConvLSTM
import dlacs.preprocess
import dlacs.function
# for visualization
import dlacs.visual

# %% [markdown]
# # Test BayesConvLSTM module <br>
# The testing device is Dell Inspirion 5680 with Intel Core i7-8700 x64 CPU and Nvidia GTX 1060 6GB GPU.<br>
# Here is a benchmark about cpu v.s. gtx 1060 <br>
# https://www.analyticsindiamag.com/deep-learning-tensorflow-benchmark-intel-i5-4210u-vs-geforce-nvidia-1060-6gb/

# %%
if __name__=="__main__":
    print ('*******************  create basic dimensions for tensor and network  *********************')
    # specifications of neural network
    input_channels = 3
    hidden_channels = [3, 2, 1] # number of channels & hidden layers, the channels of last layer is the channels of output, too
    #hidden_channels = [3, 3, 3, 3, 2]
    #hidden_channels = [2]
    kernel_size = 3
    # here we input a sequence and predict the next step only
    #step = 1 # how many steps to predict ahead
    #effective_step = [0] # step to output
    batch_size = 1
    #num_layers = 1
    learning_rate = 0.005
    num_epochs = 1500
    print ('*******************  check the environment  *********************')
    print ("Pytorch version {}".format(torch.__version__))
    # check if CUDA is available
    use_cuda = torch.cuda.is_available()
    print("Is CUDA available? {}".format(use_cuda))
    # CUDA settings torch.__version__ must > 0.4
    # !!! This is important for the model!!! The first option is gpu
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# *******************  create basic dimensions for tensor and network  *********************
# *******************  check the environment  *********************
# Pytorch version 1.1.0
# Is CUDA available? False

# %%
    print ('*******************  pretest model  *********************')
    model = dlacs.BayesConvLSTM.BayesConvLSTM(input_channels, hidden_channels, kernel_size).to(device)
# Out:
# *******************  pretest model  *********************

# %%
    for name, param in model.named_parameters():
        if param.requires_grad:
            print (name)
            print (param.data)
            print (param.size())
# Out:
# cell0.Wxi_mu tensor([[[[ 0.1448,  0.0681, -0.0892],
#           [-0.0036,  0.0582,  0.0423],
#           [ 0.1576,  0.0173, -0.1491]],
#
#          [[ 0.1091, -0.0483,  0.1894],
#           [-0.0353,  0.0336,  0.1602],
#           [-0.1375,  0.0079,  0.0645]],
#
#          [[ 0.0242, -0.1720, -0.0150],
#           [-0.1312, -0.0082,  0.1006],
#           [-0.1450, -0.1291,  0.0857]]],
#
#
#         [[[ 0.1788, -0.0414, -0.0803],
#           [-0.0154, -0.1765,  0.1455],
#           [ 0.1095, -0.1798,  0.1834]],
#
#          [[ 0.1908, -0.0526,  0.1139],
#           [ 0.0488,  0.1360, -0.1795],
#           [-0.0376, -0.0881,  0.0705]],
#
#          [[-0.1911,  0.1239, -0.0404],
#           [-0.0517,  0.1522, -0.1399],
#           [-0.1442,  0.0260, -0.0114]]],
#
#
#         [[[-0.1853, -0.0356,  0.0825],
#           [-0.1120,  0.0214, -0.1222],
#           [ 0.0750, -0.1075,  0.1110]],
#
#          [[-0.0745, -0.1683,  0.1485],
#           [ 0.1262, -0.0214, -0.1113],
#           [-0.1810,  0.0103, -0.0476]],
#
#          [[ 0.1040,  0.0421,  0.0974],
#           [-0.1443, -0.0437,  0.0162],
#           [-0.0710,  0.1013, -0.0728]]]])
# cell0.Whi_mu tensor([[[[-0.1844,  0.0014, -0.1673],
#           [ 0.1451,  0.1665, -0.1025],
#           [-0.1151,  0.0554, -0.0472]],
#
#          [[-0.0943, -0.1878,  0.0713],
#           [-0.0857,  0.0853, -0.0266],
#           [-0.0916, -0.1494,  0.0013]],
#
#          [[ 0.0981,  0.0767,  0.0817],
#           [-0.1671,  0.1180,  0.0612],
#           [-0.0491,  0.0098,  0.1671]]],
#
#
#         [[[ 0.0416, -0.1181,  0.1900],
#           [ 0.1540, -0.0235,  0.0682],
#           [ 0.1072,  0.0661, -0.1240]],
#
#          [[ 0.0186,  0.0464, -0.0157],
#           [-0.0435,  0.0320,  0.1623],
#           [ 0.1489,  0.0489,  0.0882]],
#
#          [[ 0.0376,  0.0492, -0.1195],
#           [ 0.0317,  0.1644, -0.1798],
#           [ 0.1261,  0.0250, -0.1299]]],
#
#
#         [[[-0.0797,  0.0744, -0.0233],
#           [ 0.0585, -0.1391, -0.0069],
#           [ 0.1202,  0.0708, -0.1702]],
#
#          [[ 0.0746, -0.1669,  0.0724],
#           [-0.1446, -0.1293,  0.0556],
#           [-0.1364, -0.1810,  0.1607]],
#
#          [[-0.0774, -0.1041,  0.1060],
#           [ 0.1559,  0.0104,  0.1283],
#           [-0.1498, -0.0508, -0.1117]]]])
# cell0.Wxf_mu tensor([[[[ 0.0467,  0.1805,  0.1655],
#           [ 0.1840, -0.0940,  0.0398],
#           [ 0.1639,  0.0340, -0.0899]],
#
#          [[-0.0713, -0.1841,  0.0263],
#           [ 0.1017, -0.0740,  0.1556],
#           [-0.1584, -0.1623, -0.1513]],
#
#          [[-0.1517,  0.1466, -0.0855],
#           [-0.0785,  0.1068,  0.0503],
#           [-0.0064, -0.0454,  0.0132]]],
#
#
#         [[[-0.1106, -0.0501, -0.0817],
#           [ 0.0012,  0.0143, -0.0248],
#           [ 0.0973, -0.0843, -0.0298]],
#
#          [[-0.0134, -0.0957,  0.0010],
#           [ 0.1259,  0.1574,  0.0093],
#           [ 0.1328,  0.0111, -0.0917]],
#
#          [[ 0.0341,  0.0224, -0.0212],
#           [ 0.0186, -0.0804,  0.1298],
#           [-0.1497,  0.0830,  0.0738]]],
#
#
#         [[[-0.0441, -0.0574, -0.0870],
#           [ 0.0452, -0.0351, -0.1638],
#           [ 0.1215,  0.0025, -0.0820]],
#
#          [[ 0.0410,  0.0788,  0.0647],
#           [ 0.0553,  0.0015,  0.1333],
#           [-0.0010, -0.1068,  0.1757]],
#
#          [[ 0.0304,  0.0480,  0.1866],
#           [-0.0342,  0.1046, -0.0842],
#           [ 0.1265,  0.0405, -0.0436]]]])
# cell0.Whf_mu tensor([[[[-0.0174, -0.0375, -0.0061],
#           [ 0.1386,  0.0172, -0.1074],
#           [-0.0525,  0.1861,  0.1650]],
#
#          [[-0.1514,  0.1658,  0.1917],
#           [-0.1167,  0.1032, -0.1071],
#           [ 0.0259,  0.1871,  0.1878]],
#
#          [[-0.1411,  0.0406, -0.1710],
#           [-0.0210, -0.0704, -0.1722],
#           [-0.1675,  0.0177, -0.0785]]],
#
#
#         [[[-0.1813, -0.0108,  0.0949],
#           [ 0.0640, -0.0301,  0.0902],
#           [-0.0170, -0.0528, -0.1808]],
#
#          [[ 0.1517, -0.0581, -0.0703],
#           [-0.1482, -0.0605,  0.1453],
#           [ 0.1615,  0.0123,  0.1376]],
#
#          [[ 0.0102,  0.1494, -0.1820],
#           [-0.1873,  0.1070,  0.0361],
#           [-0.1396, -0.1059, -0.1905]]],
#
#
#         [[[-0.1328,  0.0144,  0.0756],
#           [-0.1213, -0.1581, -0.0284],
#           [ 0.1236, -0.0761, -0.0773]],
#
#          [[ 0.1425,  0.1296, -0.1711],
#           [ 0.0755, -0.1263, -0.1212],
#           [-0.1316, -0.1069, -0.1224]],
#
#          [[-0.0626, -0.1562, -0.1548],
#           [ 0.0604,  0.1315,  0.1908],
#           [ 0.0440,  0.1092, -0.0207]]]])
# cell0.Wxc_mu tensor([[[[-0.0964,  0.1639,  0.0960],
#           [ 0.0134, -0.0264,  0.1207],
#           [-0.1286,  0.0522,  0.0130]],
#
#          [[-0.1881, -0.0226,  0.0367],
#           [ 0.0868,  0.1522,  0.0060],
#           [ 0.0890,  0.0432,  0.0163]],
#
#          [[-0.0905,  0.0109,  0.1085],
#           [ 0.0018,  0.0599,  0.0243],
#           [ 0.0430, -0.1396,  0.1298]]],
#
#
#         [[[-0.0349, -0.0605, -0.1591],
#           [-0.0360, -0.1414, -0.1014],
#           [-0.0239, -0.0070, -0.1051]],
#
#          [[ 0.0981, -0.0739,  0.1608],
#           [ 0.1774, -0.0573, -0.0383],
#           [ 0.1334,  0.1857, -0.1695]],
#
#          [[-0.1689,  0.0272, -0.0998],
#           [ 0.0220, -0.1602,  0.1098],
#           [ 0.1667,  0.1375, -0.1018]]],
#
#
#         [[[-0.0003, -0.0308, -0.0374],
#           [ 0.0321, -0.0664,  0.0564],
#           [-0.1482, -0.1683, -0.0380]],
#
#          [[ 0.1265,  0.0826,  0.0331],
#           [ 0.0096, -0.0821, -0.0213],
#           [ 0.0505, -0.1610, -0.0037]],
#
#          [[ 0.1871,  0.1848, -0.0172],
#           [-0.1197, -0.1462, -0.0374],
#           [ 0.0837, -0.1066,  0.0665]]]])
# cell0.Whc_mu tensor([[[[-0.1916,  0.0365,  0.1021],
#           [-0.1316, -0.0883, -0.0995],
#           [-0.0495,  0.0110, -0.0164]],
#
#          [[-0.0827, -0.1273, -0.0456],
#           [-0.0123, -0.0939,  0.0184],
#           [-0.1345,  0.0263, -0.1312]],
#
#          [[ 0.1860, -0.0135,  0.1224],
#           [-0.1389,  0.0381, -0.1371],
#           [-0.0029, -0.1819,  0.0908]]],
#
#
#         [[[-0.1355,  0.1544,  0.1211],
#           [ 0.1027, -0.1222,  0.1598],
#           [-0.1316, -0.0278,  0.0681]],
#
#          [[ 0.0675,  0.1321, -0.1323],
#           [-0.0124,  0.0525, -0.0341],
#           [-0.1031,  0.1510, -0.0623]],
#
#          [[-0.0484, -0.0036, -0.1412],
#           [-0.0600, -0.1862,  0.1384],
#           [-0.1674, -0.1511, -0.1284]]],
#
#
#         [[[-0.0471,  0.0324,  0.1213],
#           [ 0.1648, -0.0259, -0.1476],
#           [-0.0800,  0.0895, -0.1667]],
#
#          [[ 0.0389, -0.1376,  0.0097],
#           [-0.1561, -0.0364,  0.0949],
#           [ 0.0678, -0.0553, -0.0846]],
#
#          [[ 0.0386,  0.0620,  0.1408],
#           [-0.1923, -0.0053, -0.0004],
#           [ 0.0813, -0.1465,  0.0900]]]])
# cell0.Wxo_mu tensor([[[[-0.1147,  0.0531, -0.0385],
#           [-0.0228,  0.0394, -0.0915],
#           [-0.1580,  0.0637,  0.1858]],
#
#          [[-0.0703, -0.1579,  0.0480],
#           [-0.0562, -0.1815, -0.0645],
#           [ 0.0409, -0.0930,  0.0834]],
#
#          [[ 0.0231, -0.0943,  0.1004],
#           [ 0.0004,  0.0729,  0.1641],
#           [ 0.1004, -0.0939, -0.1623]]],
#
#
#         [[[-0.1720, -0.0008, -0.1323],
#           [-0.0562, -0.1146,  0.1270],
#           [-0.1155,  0.1887, -0.1573]],
#
#          [[-0.0634,  0.0287, -0.0590],
#           [-0.0450,  0.0338, -0.0136],
#           [-0.0516, -0.0115, -0.0070]],
#
#          [[-0.0657,  0.1579, -0.1681],
#           [ 0.1852,  0.0765, -0.0931],
#           [-0.1077, -0.1773,  0.1495]]],
#
#
#         [[[-0.0930,  0.1145,  0.1764],
#           [ 0.1487,  0.0453,  0.1348],
#           [ 0.0293, -0.0844,  0.1727]],
#
#          [[ 0.0809, -0.0847, -0.0634],
#           [-0.1102,  0.1386, -0.0988],
#           [-0.1735, -0.1821, -0.1163]],
#
#          [[-0.1515,  0.1756, -0.0041],
#           [ 0.1007,  0.0773, -0.0555],
#           [ 0.1376,  0.0324,  0.1857]]]])
# cell0.Who_mu tensor([[[[-0.0817,  0.1265, -0.0289],
#           [ 0.0115, -0.1614,  0.0522],
#           [-0.0772, -0.1256,  0.0412]],
#
#          [[-0.1054, -0.1135, -0.0165],
#           [ 0.0209,  0.0245,  0.0283],
#           [-0.1256,  0.1301, -0.1731]],
#
#          [[-0.1709,  0.1224, -0.1518],
#           [ 0.1660, -0.1615, -0.1294],
#           [-0.1359, -0.1157, -0.1577]]],
#
#
#         [[[ 0.1401,  0.1304,  0.1208],
#           [ 0.1914, -0.0124,  0.0298],
#           [ 0.0892,  0.1179, -0.0940]],
#
#          [[ 0.0634,  0.0751,  0.0418],
#           [-0.1216, -0.1682, -0.0485],
#           [ 0.1015,  0.1491, -0.0977]],
#
#          [[ 0.1400,  0.0059,  0.1000],
#           [-0.1821,  0.1522, -0.0279],
#           [ 0.0947, -0.1725,  0.0401]]],
#
#
#         [[[-0.1151,  0.1012, -0.0649],
#           [-0.1585,  0.1506, -0.0730],
#           [-0.1150,  0.0746, -0.0418]],
#
#          [[-0.1744, -0.0034,  0.1678],
#           [-0.1621,  0.1130,  0.0275],
#           [ 0.1138,  0.1483,  0.0467]],
#
#          [[ 0.1133,  0.1013,  0.0126],
#           [ 0.0154, -0.0323,  0.0007],
#           [ 0.0532,  0.0586, -0.1134]]]])
# cell0.Wxi_bias tensor([[[[-0.1005]],
#
#          [[-0.1790]],
#
#          [[-0.1898]]]])
# cell0.Wxf_bias tensor([[[[-0.1221]],
#
#          [[ 0.0966]],
#
#          [[ 0.1224]]]])
# cell0.Wxc_bias tensor([[[[0.1676]],
#
#          [[0.0535]],
#
#          [[0.0165]]]])
# cell0.Wxo_bias tensor([[[[-0.1858]],
#
#          [[ 0.0571]],
#
#          [[ 0.1387]]]])
# cell0.Wxi_log_alpha tensor([[5.]])
# cell0.Whi_log_alpha tensor([[5.]])
# cell0.Wxf_log_alpha tensor([[5.]])
# cell0.Whf_log_alpha tensor([[5.]])
# cell0.Wxc_log_alpha tensor([[5.]])
# cell0.Whc_log_alpha tensor([[5.]])
# cell0.Wxo_log_alpha tensor([[5.]])
# cell0.Who_log_alpha tensor([[5.]])
# cell1.Wxi_mu tensor([[[[-0.0602,  0.1125, -0.1426],
#           [-0.0998, -0.1620,  0.1769],
#           [ 0.1007, -0.1004,  0.1522]],
#
#          [[-0.0082, -0.1766,  0.0537],
#           [-0.0478, -0.1812, -0.0865],
#           [-0.0011, -0.0774,  0.1912]],
#
#          [[-0.1025, -0.0148,  0.1343],
#           [ 0.0782, -0.0856,  0.0838],
#           [-0.0558,  0.0638,  0.1710]]],
#
#
#         [[[ 0.1102, -0.0882, -0.0923],
#           [ 0.1292, -0.0693, -0.0069],
#           [ 0.0096, -0.1471,  0.0344]],
#
#          [[ 0.0749,  0.1689,  0.1850],
#           [ 0.0554,  0.0976, -0.1919],
#           [-0.1620, -0.1248,  0.1326]],
#
#          [[ 0.1593,  0.0544,  0.0197],
#           [ 0.1046, -0.1737,  0.0084],
#           [-0.0844,  0.0650, -0.0559]]]])
# cell1.Whi_mu tensor([[[[-0.0552, -0.1915, -0.0445],
#           [ 0.0941, -0.0484,  0.0923],
#           [-0.0975, -0.1476, -0.1434]],
#
#          [[ 0.1467, -0.0030, -0.0212],
#           [-0.1858, -0.1209, -0.0203],
#           [ 0.1234,  0.0931, -0.1843]],
#
#          [[-0.1767,  0.1308, -0.0905],
#           [-0.0164, -0.0279,  0.0223],
#           [-0.0189,  0.1080, -0.0639]]],
#
#
#         [[[ 0.1768,  0.0806,  0.1696],
#           [ 0.0584,  0.0049, -0.1583],
#           [-0.1618,  0.0009,  0.1280]],
#
#          [[ 0.1529,  0.0564,  0.0993],
#           [-0.0769, -0.1117,  0.0589],
#           [-0.0584,  0.0855, -0.0413]],
#
#          [[ 0.1559,  0.1529,  0.0564],
#           [-0.1438,  0.1241, -0.1678],
#           [-0.0128,  0.1615, -0.1753]]]])
# cell1.Wxf_mu tensor([[[[-0.1833, -0.0244, -0.1024],
#           [ 0.1743,  0.1056, -0.0872],
#           [ 0.0559, -0.1881,  0.0913]],
#
#          [[-0.1241, -0.0870, -0.0267],
#           [ 0.0694,  0.0198, -0.0983],
#           [-0.0906,  0.1603,  0.0267]],
#
#          [[ 0.0396, -0.0858, -0.0640],
#           [-0.1446,  0.1259, -0.1160],
#           [ 0.1746, -0.0853,  0.1149]]],
#
#
#         [[[ 0.0317,  0.0179,  0.1902],
#           [ 0.1248, -0.1347, -0.1153],
#           [ 0.0801, -0.1594, -0.1835]],
#
#          [[-0.0834,  0.1775, -0.0613],
#           [-0.1751, -0.0368,  0.1448],
#           [ 0.1760, -0.0248,  0.0102]],
#
#          [[ 0.0650, -0.0999, -0.0157],
#           [-0.0225, -0.1729, -0.1726],
#           [ 0.0406,  0.1438,  0.1093]]]])
# cell1.Whf_mu tensor([[[[ 0.1648,  0.0461,  0.1168],
#           [-0.0867, -0.1030,  0.0978],
#           [-0.1881, -0.0649, -0.0961]],
#
#          [[-0.0133, -0.0121,  0.0378],
#           [ 0.0292, -0.0631, -0.1139],
#           [ 0.0431, -0.0774, -0.1212]],
#
#          [[-0.0914, -0.1160,  0.0862],
#           [ 0.1889,  0.1318, -0.1491],
#           [-0.0429,  0.0158, -0.0669]]],
#
#
#         [[[-0.0419, -0.1364,  0.1039],
#           [ 0.0048, -0.0991,  0.1644],
#           [-0.0307, -0.0071, -0.0870]],
#
#          [[ 0.0611,  0.1823, -0.0921],
#           [ 0.1836, -0.1714, -0.1453],
#           [ 0.1157, -0.0351,  0.0321]],
#
#          [[-0.0332,  0.0223, -0.0291],
#           [ 0.0076, -0.0939, -0.1245],
#           [ 0.1794, -0.0031, -0.1852]]]])
# cell1.Wxc_mu tensor([[[[ 0.1325,  0.0431, -0.1824],
#           [ 0.1248,  0.1692, -0.0998],
#           [-0.0895, -0.1343, -0.0928]],
#
#          [[-0.1922,  0.0800, -0.0768],
#           [ 0.1608, -0.0338, -0.0573],
#           [-0.1645,  0.1600,  0.0726]],
#
#          [[ 0.1781,  0.1512,  0.0871],
#           [-0.0317,  0.0712,  0.1306],
#           [-0.0233,  0.1805,  0.0602]]],
#
#
#         [[[ 0.1611,  0.0313, -0.0279],
#           [ 0.0798, -0.0412,  0.0803],
#           [-0.1729,  0.1470, -0.1394]],
#
#          [[ 0.1868, -0.1528,  0.0790],
#           [-0.0179,  0.0148,  0.1625],
#           [ 0.1914, -0.0860,  0.1521]],
#
#          [[ 0.0089, -0.1857,  0.1412],
#           [ 0.1422,  0.1040,  0.1217],
#           [-0.1642, -0.0132,  0.1044]]]])
# cell1.Whc_mu tensor([[[[ 0.0478, -0.0148,  0.1294],
#           [ 0.1862, -0.0638, -0.1487],
#           [ 0.0678, -0.1502, -0.1898]],
#
#          [[ 0.0649, -0.0918, -0.1714],
#           [-0.1126, -0.0497, -0.0739],
#           [ 0.0524,  0.1601,  0.1559]],
#
#          [[ 0.0221,  0.1648,  0.1710],
#           [-0.1574,  0.1920,  0.0468],
#           [-0.1832, -0.1481, -0.0620]]],
#
#
#         [[[-0.0913, -0.0136,  0.0296],
#           [-0.1426,  0.1777,  0.1532],
#           [-0.0520,  0.1033, -0.0218]],
#
#          [[-0.0177,  0.0963, -0.0186],
#           [-0.0775,  0.0004, -0.0391],
#           [ 0.1383,  0.1768,  0.0313]],
#
#          [[ 0.1881,  0.1393, -0.0394],
#           [-0.0316, -0.1295, -0.0669],
#           [-0.0233,  0.0641,  0.0463]]]])
# cell1.Wxo_mu tensor([[[[ 0.1675,  0.1415,  0.1404],
#           [-0.0779, -0.1011, -0.1039],
#           [-0.1269, -0.0261, -0.0650]],
#
#          [[-0.1794, -0.1343, -0.0767],
#           [ 0.0712, -0.1708, -0.1230],
#           [ 0.0408,  0.0174, -0.1500]],
#
#          [[ 0.1407,  0.1138,  0.1400],
#           [ 0.0933,  0.1408, -0.0212],
#           [-0.0821,  0.1300, -0.0414]]],
#
#
#         [[[ 0.1320,  0.1724, -0.0206],
#           [ 0.0507,  0.1000, -0.0234],
#           [ 0.0713, -0.0376,  0.0975]],
#
#          [[ 0.1398, -0.1754, -0.1607],
#           [-0.0689,  0.1001, -0.1246],
#           [-0.1234,  0.1199, -0.0201]],
#
#          [[-0.1020,  0.1240,  0.1863],
#           [ 0.1131, -0.0089, -0.0116],
#           [ 0.1826, -0.1806,  0.1811]]]])
# cell1.Who_mu tensor([[[[ 0.0107, -0.1022, -0.1134],
#           [ 0.1818, -0.1843,  0.1015],
#           [ 0.0151, -0.0017, -0.0818]],
#
#          [[-0.1249, -0.0908,  0.0109],
#           [ 0.1862, -0.0820, -0.0284],
#           [ 0.1465, -0.1484,  0.0643]],
#
#          [[-0.0597, -0.1560, -0.0756],
#           [ 0.1373, -0.0443,  0.0561],
#           [ 0.0129,  0.0513, -0.0585]]],
#
#
#         [[[ 0.0174, -0.1214, -0.1632],
#           [-0.1879,  0.0922, -0.0398],
#           [-0.0818, -0.0493, -0.1901]],
#
#          [[ 0.1836, -0.0776, -0.0413],
#           [-0.0375, -0.1451,  0.0761],
#           [ 0.0881,  0.1576,  0.0678]],
#
#          [[ 0.0311,  0.0734, -0.1680],
#           [ 0.0675,  0.0515,  0.1333],
#           [-0.0175,  0.1246, -0.1063]]]])
# cell1.Wxi_bias tensor([[[[0.1044]],
#
#          [[0.1013]]]])
# cell1.Wxf_bias tensor([[[[-0.0196]],
#
#          [[ 0.1129]]]])
# cell1.Wxc_bias tensor([[[[-0.0506]],
#
#          [[-0.1332]]]])
# cell1.Wxo_bias tensor([[[[-0.1197]],
#
#          [[ 0.1113]]]])
# cell1.Wxi_log_alpha tensor([[5.]])
# cell1.Whi_log_alpha tensor([[5.]])
# cell1.Wxf_log_alpha tensor([[5.]])
# cell1.Whf_log_alpha tensor([[5.]])
# cell1.Wxc_log_alpha tensor([[5.]])
# cell1.Whc_log_alpha tensor([[5.]])
# cell1.Wxo_log_alpha tensor([[5.]])
# cell1.Who_log_alpha tensor([[5.]])
# cell2.Wxi_mu tensor([[[[-0.1560, -0.1696,  0.0572],
#           [ 0.2081, -0.2049, -0.1682],
#           [ 0.0409, -0.1532,  0.1762]],
#
#          [[ 0.0817, -0.0048, -0.0554],
#           [ 0.1828,  0.1282,  0.1368],
#           [ 0.1502,  0.0678,  0.0257]]]])
# cell2.Whi_mu tensor([[[[-0.1326, -0.1483, -0.0138],
#           [-0.0020,  0.0287,  0.1617],
#           [ 0.0438, -0.0064,  0.0932]],
#
#          [[ 0.1182,  0.1533,  0.1419],
#           [-0.1942,  0.1569,  0.1729],
#           [-0.1865,  0.1410,  0.1842]]]])
# cell2.Wxf_mu tensor([[[[ 0.1693, -0.0185, -0.2277],
#           [ 0.1166, -0.0877, -0.0863],
#           [ 0.2088, -0.1816,  0.0254]],
#
#          [[-0.1192, -0.1398,  0.0830],
#           [-0.0396,  0.0851, -0.2331],
#           [ 0.1376, -0.1923, -0.1975]]]])
# cell2.Whf_mu tensor([[[[-0.0083,  0.2333,  0.2325],
#           [ 0.1404, -0.2303,  0.0349],
#           [ 0.2186, -0.1034, -0.1593]],
#
#          [[-0.1401,  0.0754, -0.0563],
#           [ 0.1465,  0.2291, -0.0458],
#           [ 0.1985,  0.1217,  0.0749]]]])
# cell2.Wxc_mu tensor([[[[-0.1315, -0.1211, -0.0345],
#           [-0.1113, -0.0986,  0.0932],
#           [-0.1729, -0.0458, -0.1758]],
#
#          [[ 0.0801, -0.0177, -0.1971],
#           [-0.0077,  0.0053, -0.1466],
#           [ 0.1655,  0.0098, -0.0185]]]])
# cell2.Whc_mu tensor([[[[-0.1990,  0.0766,  0.1344],
#           [ 0.2279, -0.0996, -0.0176],
#           [ 0.0003, -0.2345,  0.0953]],
#
#          [[ 0.1095,  0.1688,  0.0325],
#           [-0.0207, -0.1997,  0.1335],
#           [-0.1464, -0.1453,  0.0160]]]])
# cell2.Wxo_mu tensor([[[[ 0.0942,  0.1808, -0.0906],
#           [-0.1244, -0.0141, -0.2260],
#           [-0.1794,  0.1794, -0.0864]],
#
#          [[-0.0400,  0.1582,  0.0946],
#           [ 0.0142, -0.0870, -0.0239],
#           [ 0.1486, -0.1695, -0.1209]]]])
# cell2.Who_mu tensor([[[[-0.0685, -0.2100,  0.1034],
#           [-0.0832,  0.1938, -0.1432],
#           [ 0.0115,  0.1870, -0.1149]],
#
#          [[ 0.1058, -0.1101, -0.0085],
#           [-0.0730,  0.0777,  0.1624],
#           [-0.0623,  0.0463, -0.1469]]]])
# cell2.Wxi_bias tensor([[[[0.1226]]]])
# cell2.Wxf_bias tensor([[[[0.2095]]]])
# cell2.Wxc_bias tensor([[[[0.1634]]]])
# cell2.Wxo_bias tensor([[[[-0.0553]]]])
# cell2.Wxi_log_alpha tensor([[5.]])
# cell2.Whi_log_alpha tensor([[5.]])
# cell2.Wxf_log_alpha tensor([[5.]])
# cell2.Whf_log_alpha tensor([[5.]])
# cell2.Wxc_log_alpha tensor([[5.]])
# cell2.Whc_log_alpha tensor([[5.]])
# cell2.Wxo_log_alpha tensor([[5.]])
# cell2.Who_log_alpha tensor([[5.]])

# %%
    print('##############################################################')
    print('#############  preview model parameters matrix  ###############')
    print('##############################################################')
    print('Number of parameter matrices: ', len(list(model.parameters())))
    for i in range(len(list(model.parameters()))):
        print(list(model.parameters())[i].size())
# Out:
# ##############################################################
# #############  preview model parameters matrix  ###############
# ##############################################################
# Number of parameter matrices:  60
# torch.Size([3, 3, 3, 3])
# torch.Size([3, 3, 3, 3])
# torch.Size([3, 3, 3, 3])
# torch.Size([3, 3, 3, 3])
# torch.Size([3, 3, 3, 3])
# torch.Size([3, 3, 3, 3])
# torch.Size([3, 3, 3, 3])
# torch.Size([3, 3, 3, 3])
# torch.Size([1, 3, 1, 1])
# torch.Size([1, 3, 1, 1])
# torch.Size([1, 3, 1, 1])
# torch.Size([1, 3, 1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([2, 3, 3, 3])
# torch.Size([2, 3, 3, 3])
# torch.Size([2, 3, 3, 3])
# torch.Size([2, 3, 3, 3])
# torch.Size([2, 3, 3, 3])
# torch.Size([2, 3, 3, 3])
# torch.Size([2, 3, 3, 3])
# torch.Size([2, 3, 3, 3])
# torch.Size([1, 2, 1, 1])
# torch.Size([1, 2, 1, 1])
# torch.Size([1, 2, 1, 1])
# torch.Size([1, 2, 1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 2, 3, 3])
# torch.Size([1, 2, 3, 3])
# torch.Size([1, 2, 3, 3])
# torch.Size([1, 2, 3, 3])
# torch.Size([1, 2, 3, 3])
# torch.Size([1, 2, 3, 3])
# torch.Size([1, 2, 3, 3])
# torch.Size([1, 2, 3, 3])
# torch.Size([1, 1, 1, 1])
# torch.Size([1, 1, 1, 1])
# torch.Size([1, 1, 1, 1])
# torch.Size([1, 1, 1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
# torch.Size([1, 1])
